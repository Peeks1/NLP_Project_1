# %%
import nltk
import math
from itertools import combinations
from nltk.corpus import stopwords
import string

# %%
file_name = "text.txt"
val = {}
"""
reads the file and tokenizes the word
"""
def file_reading(file_name):
    file = open(file_name)
    f = file.read()
    word = nltk.word_tokenize(f)
    file.close()
    return word

# %%
"""
reads in the tokenized words and gets the unigram count of them
"""
def unigram_counting(text):
    unigram = nltk.ngrams(text,1) # does the unigram modeling
    unigram_list = [ ' '.join(grams) for grams in unigram] ### joins the unigram into a list 
    unigram_count = len(unigram_list)
    return unigram_count

# %%
"""
parses the file and gets the collocations using a sliding window method
"""
def collocation_calculator(file_name):
    file = open(file_name).read()
    sentences = nltk.sent_tokenize(file) #tokenzie the file into sentences
    new_list = []
    word_dict = {}
    for i in range (len(sentences)): ## reads each sentences and removes all the new lines and punctuations from each sentence
        s = ' '.join(sentences[i].split('\n'))# splits the sentences where there are newlines in them
        table = str.maketrans((string.punctuation),' '*len(string.punctuation))# replaces all punctuations with a space
        new_s = s.translate(table) 
        new_s = new_s.lower()#pareses the words and make them all lower case
        new_list.append(new_s) 
    collacations_counter ={}
    for i in range(len(new_list)):
        counter = 0
        word = nltk.word_tokenize(new_list[i])# tokenize the words from the sentence list
        for index in range(len(word)):# counts the frequnecy of each word in the test
            words = word[index].lower()
            if words in word_dict:
                word_dict[words]+=1
            else:
                word_dict[words]=1
            if len(word[index:index+4]) != 1:# makes a sliding window that gets the combination of words in the text
                sub_list = combinations(word[index:index+4],2)
                for item in sub_list:
                    if item in collacations_counter: #adds them into the collocations dictionary and gets its frequnecy
                        collacations_counter[item] +=1
                    else:
                        collacations_counter[item] =1
    stoplist = []
    for i in stopwords.words('english'):
        stoplist.append(i)
    stopwords.words('english')
    for i in collacations_counter: #set all the collocations that are in the stoplist to None
        for j in stoplist:
            if j in i:
                collacations_counter[i] = None
    updated_dict = {}
    for i in collacations_counter:#makes a new dictionary that does not contain the stoplist
        if collacations_counter[i]!= None:
            updated_dict[i]= collacations_counter[i]
    return updated_dict,word_dict #gets the word count and collocations dictionaery

# %%
text = file_reading(file_name)
size = unigram_counting(text)
val,word_count = collocation_calculator(file_name)
"""
does the PMI for each collocations and store their value in a dictionary that has the collocations as key
"""
def pointwise_mutual_information(size,collocation_count,word_count): 
    PMI = {}
    for i in collocation_count:
        if collocation_count[i]>2:
            word_1 = i[0]
            word_2 = i[1]
            PMI[i] = math.log2(size*((collocation_count[i])/(word_count[word_1]*word_count[word_2])))
        
    return PMI

# %%
PMI = pointwise_mutual_information(size,val,word_count)

# %%
# sorts the collocations in ascending order
sort_order = sorted(PMI.items(), key=lambda x:x[1]) 
for i in sort_order:
    print(i[0],i[1])
# Out:
# ('states', 'united') 0.6378912877573397
# ('government', 'states') 0.7395627056522452
# ('states', 'one') 0.8358306653692488
# ('states', 'upon') 0.9834882885383345
# ('states', 'states') 0.9928160906934538
# ('government', 'war') 1.030629836834847
# ('government', 'new') 1.0870607071363254
# ('new', 'american') 1.1709784198723703
# ('government', 'state') 1.3074700421936714
# ('found', 'american') 3.0943343286813834
# ('would', 'upon') 3.095330857540862
# ('upon', 'america') 3.097017234168749
# ('states', 'carolina') 3.1001712687036673
# ('states', 'representatives') 3.1001712687036673
# ('made', 'law') 3.1007138647481955
# ('new', 'land') 3.100866506661356
# ('england', 'labor') 3.1028862919295905
# ('federal', 'state') 3.106832173497745
# ('way', 'american') 3.106934365461017
# ('time', 'could') 3.1077180777570157
# ('america', 'could') 3.1127713054833013
# ('new', 'powers') 3.1132502311171883
# ('many', 'new') 3.1132502311171883
# ('civil', 'american') 3.1164571395795235
# ('country', 'labor') 3.1187693335362456
# ('president', 'made') 3.1189925984665043
# ('union', 'new') 3.1194821848287027
# ('history', 'state') 3.1208487518790453
# ('made', 'england') 3.1216228545111764
# ('england', 'made') 3.1216228545111764
# ('new', 'made') 3.1288808828309524
# ('slavery', 'upon') 3.129438711861126
# ('commerce', 'american') 3.1324694575681544
# ('men', 'first') 3.1337529478730057
# ('years', 'national') 3.134117389703356
# ('american', 'came') 3.135693358442441
# ('new', 'massachusetts') 3.138341212080019
# ('one', 'women') 3.1422457608852867
# ('law', 'could') 3.1486483418118976
# ('labor', 'one') 3.1499814096648917
# ('shall', 'one') 3.1499814096648917
# ('new', 'election') 3.151052263829573
# ('years', 'congress') 3.1546427870347546
# ('old', 'state') 3.157529415205514
# ('american', 'farmers') 3.158464666101099
# ('another', 'american') 3.158464666101099
# ('war', 'power') 3.159912853779814
# ('state', 'many') 3.163734564732222
# ('england', 'people') 3.164691576403062
# ('also', 'new') 3.1671002050614425
# ('made', 'one') 3.1687179722464776
# ('passed', 'american') 3.171640054848832
# ('one', 'even') 3.173440382488881
# ('two', 'congress') 3.173440382488881
# ('people', 'country') 3.1805746180097176
# ('states', 'took') 3.180789728911952
# ('states', 'amendment') 3.180789728911952
# ('west', 'great') 3.181345580574227
# ('power', 'first') 3.1829964668928548
# ('american', 'territory') 3.18493687746229
# ('american', 'public') 3.191631530036298
# ('new', 'president') 3.192496982126924
# ('three', 'new') 3.196444166643587
# ('held', 'american') 3.1983573932246117
# ('rights', 'states') 3.200827482148497
# ('railways', 'new') 3.2030469014678338
# ('men', 'one') 3.2069372944769676
# ('spirit', 'american') 3.2119039250625594
# ('public', 'president') 3.213150092290852
# ('territory', 'new') 3.216343724081292
# ('new', 'territory') 3.216343724081292
# ('general', 'government') 3.217832829708995
# ('many', 'great') 3.2181823487545986
# ('time', 'england') 3.2191393604254386
# ('english', 'state') 3.2229737681068977
# ('government', 'though') 3.223638451390201
# ('war', 'french') 3.2291755162169276
# ('held', 'new') 3.2297642398436133
# ('one', 'old') 3.239991575397487
# ('states', 'part') 3.240028932286628
# ('new', 'high') 3.2433107716815615
# ('spirit', 'new') 3.2433107716815615
# ('could', 'british') 3.2452216015069504
# ('labor', 'american') 3.248662475072677
# ('states', 'might') 3.248693793413756
# ('one', 'union') 3.2524286786357095
# ('constitution', 'national') 3.2558332981030484
# ('national', 'constitution') 3.2558332981030484
# ('states', 'became') 3.257411010514865
# ('states', 'issue') 3.2661812201425966
# ('states', 'four') 3.2661812201425966
# ('one', 'time') 3.2662344781607398
# ('two', 'labor') 3.2701810373272306
# ('war', 'thus') 3.2745554197209366
# ('national', 'law') 3.2866393448842235
# ('one', 'great') 3.2882607844907388
# ('country', 'president') 3.294231399805285
# ('war', 'american') 3.295119795212713
# ('states', 'held') 3.297303737638377
# ('upon', 'labor') 3.2976390328339775
# ('brought', 'new') 3.2988058842732646
# ('first', 'one') 3.3019845031099417
# ('one', 'part') 3.3054359282988712
# ('states', 'spirit') 3.3108502694763247
# ('new', 'colonies') 3.3130197434929656
# ('congress', 'general') 3.314100789425998
# ('democratic', 'states') 3.3199524765835773
# ('power', 'great') 3.321275841718702
# ('new', 'republican') 3.3244925279369144
# ('citizens', 'new') 3.327375036470036
# ('new', 'see') 3.327375036470036
# ('thus', 'new') 3.3309862900224148
# ('government', 'economic') 3.3323447108327007
# ('government', 'found') 3.3323447108327007
# ('british', 'law') 3.335733894412393
# ('labor', 'old') 3.336732230235837
# ('states', 'great') 3.338331005898432
# ('states', 'service') 3.338331005898432
# ('many', 'labor') 3.342937379762545
# ('war', 'great') 3.3439959182187855
# ('union', 'labor') 3.3491693334740598
# ('state', 'pp') 3.3492902178882984
# ('made', 'state') 3.3492902178882984
# ('power', 'american') 3.3548618789046025
# ('politics', 'new') 3.3565213821295523
# ('labor', 'pp') 3.358568031476309
# ('women', 'united') 3.3593438825522215
# ('war', 'still') 3.364053570560039
# ('declared', 'government') 3.3704798397194717
# ('government', 'commerce') 3.3704798397194717
# ('government', 'declared') 3.3704798397194717
# ('first', 'states') 3.3740810308476337
# ('pacific', 'states') 3.3758057113170947
# ('upon', 'revolution') 3.3773662253047116
# ('every', 'president') 3.3839141138445634
# ('upon', 'old') 3.3876491985665727
# ('time', 'war') 3.3923589397801845
# ('war', 'time') 3.3923589397801845
# ('old', 'men') 3.3936881150479126
# ('states', 'make') 3.3949145342647995
# ('congress', 'president') 3.3958328038253285
# ('government', 'became') 3.3964750482524164
# ('congress', 'slavery') 3.3968185879708845
# ('state', 'south') 3.3972246949520004
# ('state', 'could') 3.3972246949520004
# ('people', 'old') 3.3985375147093086
# ('war', 'early') 3.3991005176592397
# ('new', 'members') 3.4013756179138124
# ('state', 'one') 3.403738001910675
# ('war', 'war') 3.405025351616345
# ('union', 'men') 3.4061252182861357
# ('year', 'state') 3.4070057157445857
# ('south', 'many') 3.409608419407833
# ('foreign', 'government') 3.4096504370001495
# ('american', 'representatives') 3.4162624235687455
# ('made', 'political') 3.418755037551398
# ('first', 'two') 3.4221841307722807
# ('shall', 'president') 3.4221841307722807
# ('state', 'new') 3.422794601548718
# ('french', 'american') 3.424124541341716
# ('could', 'made') 3.425239071121597
# ('states', 'tariff') 3.4299614813640003
# ('congress', 'made') 3.4317523780802714
# ('states', '5') 3.4339086658806632
# ('government', 'policy') 3.436367775375929
# ('one', 'way') 3.4412127073293375
# ('president', 'even') 3.44564310359627
# ('state', 'virginia') 3.446806723802561
# ('england', 'two') 3.448273359640942
# ('upon', 'first') 3.4496421262790276
# ('government', 'military') 3.4499143072138767
# ('king', 'congress') 3.450735481447844
# ('upon', 'republican') 3.4530935514679566
# ('government', 'independence') 3.453320908657126
# ('law', 'upon') 3.4548223653847074
# ('laws', 'united') 3.457777841623564
# ('labor', 'would') 3.4594513884889704
# ('war', 'large') 3.459473135638721
# ('people', 'people') 3.4634420378416673
# ('american', 'capital') 3.464090948659361
# ('north', 'labor') 3.466208754664279
# ('came', 'one') 3.4699717003107615
# ('war', 'many') 3.4718568600945536
# ('government', 'business') 3.473931188332412
# ('constitution', 'union') 3.475546619243615
# ('government', 'must') 3.4773950436359837
# ('new', 'colonial') 3.4793781299150854
# ('government', 'free') 3.4801721283065574
# ('american', 'population') 3.4803927609884613
# ('war', 'found') 3.4843478042777507
# ('north', 'made') 3.484945317245865
# ('1', 'shall') 3.4866728572239944
# ('government', 'shall') 3.4866728572239944
# ('act', 'power') 3.4869388163068544
# ('three', 'american') 3.4869654149119476
# ('war', 'made') 3.487487511808318
# ('new', 'men') 3.489028299948805
# ('states', 'large') 3.4903340993434817
# ('large', 'states') 3.4903340993434817
# ('state', 'union') 3.491894613331099
# ('history', 'country') 3.4940269308297345
# ('new', 'capital') 3.4954977952783626
# ('union', 'first') 3.50117242691911
# ('state', 'house') 3.5086459776204237
# ('made', 'first') 3.510571124921359
# ('east', 'new') 3.511799607607463
# ('new', 'population') 3.511799607607463
# ('new', 'soon') 3.511799607607463
# ('party', 'could') 3.5127019123719365
# ('government', 'united') 3.513920919661098
# ('among', 'united') 3.513920919661098
# ('states', 'sent') 3.5152087679825113
# ('law', 'made') 3.5157513640270395
# ('men', 'would') 3.5164072733010463
# ('people', 'would') 3.521256672962442
# ('state', 'federal') 3.5218696727765884
# ('american', 'like') 3.521971864739861
# ('government', 'among') 3.5224829331645218
# ('one', 'every') 3.5267488920160184
# ('constitution', 'people') 3.5280140391377506
# ('new', 'silver') 3.5282877303960323
# ('time', 'one') 3.5292688839945336
# ('american', 'laid') 3.5304334434880564
# ('american', 'opposition') 3.5304334434880564
# ('north', 'could') 3.532879794309567
# ('south', 'north') 3.532879794309567
# ('york', 'one') 3.5343221117208192
# ('war', 'could') 3.5354219888720197
# ('war', 'however') 3.5354219888720197
# ('1', 'men') 3.5436287420360704
# ('among', 'american') 3.5475069568469983
# ('treaty', 'war') 3.548478141697466
# ('congress', 'independence') 3.5495888683741295
# ('upon', 'british') 3.5513956250797607
# ('first', 'political') 3.5520215684148626
# ('new', 'like') 3.5533787113588624
# ('act', 'president') 3.5562014787439686
# ('government', 'george') 3.5631249176618676
# ('years', 'upon') 3.5653348160376344
# ('business', 'one') 3.570199148049416
# ('laws', 'state') 3.5732550590435
# ('england', 'men') 3.5748796760205104
# ('united', 'without') 3.575321464325241
# ('commerce', 'new') 3.578913803466
# ('new', 'declared') 3.578913803466
# ('forces', 'new') 3.578913803466
# ('new', 'forces') 3.578913803466
# ('new', 'principles') 4.064340630636242
# ('new', 'cause') 4.064340630636242
# ('women', 'old') 4.065962175622438
# ('well', 'could') 4.067917069699041
# ('south', 'may') 4.067917069699041
# ('south', 'well') 4.067917069699041
# ('year', 'south') 4.067917069699041
# ('railways', 'upon') 4.0686135191650825
# ('states', 'sections') 4.069144373083043
# ('home', 'government') 4.069310304998907
# ('government', 'royal') 4.069310304998907
# ('southern', 'state') 4.075296600064638
# ('new', 'west') 4.076413462936817
# ('president', 'later') 4.078699892518471
# ('old', 'southern') 4.081475174993763
# ('war', 'question') 4.08191034177854
# ('upon', 'western') 4.08191034177854
# ('new', 'states') 4.087548021797567
# ('many', 'southern') 4.087680324520471
# ('came', 'power') 4.087949258259881
# ('new', 'legislation') 4.0885881768829195
# ('new', 'doctrine') 4.0885881768829195
# ('independence', 'united') 4.088615084928427
# ('land', 'president') 4.090978222296908
# ('king', 'war') 4.091433115897047
# ('war', 'king') 4.091433115897047
# ('england', 'new') 4.0955915646206815
# ('west', 'history') 4.096395708154507
# ('power', 'could') 4.097664413093092
# ('history', 'people') 4.098822445549047
# ('among', 'great') 4.098883420382254
# ('united', 'declared') 4.098883420382254
# ('officers', 'united') 4.098883420382254
# ('states', 'rather') 4.100171268703668
# ('new', 'service') 4.100866506661356
# ('colonial', 'government') 4.101019164726245
# ('many', 'even') 4.10336194675274
# ('colonies', '1') 4.104585779746437
# ('every', 'south') 4.1051980857785
# ('federal', 'land') 4.106832173497745
# ('american', 'liberty') 4.106934365461017
# ('democracy', 'american') 4.106934365461017
# ('american', 'industrial') 4.106934365461017
# ('power', 'may') 4.107445433885678
# ('virginia', 'south') 4.107718077757015
# ('vote', 'upon') 4.10887738937881
# ('peace', 'upon') 4.10887738937881
# ('government', 'friends') 4.111745571319304
# ('shall', 'work') 4.113455533639778
# ('president', 'right') 4.115852890935937
# ('revolution', 'history') 4.116744353546308
# ('opinion', 'one') 4.119284612441976
# ('new', 'went') 4.119482184828703
# ('said', 'government') 4.120384489593176
# ('also', 'state') 4.124475134284995
# ('man', 'one') 4.126897796551851
# ('system', 'pp') 4.126897796551851
# ('time', 'three') 4.127346884505948
# ('constitution', 'may') 4.127623315823308
# ('independence', 'could') 4.1280380621366115
# ('political', 'women') 4.129248420356413
# ('george', 'war') 4.130165510385762
# ('founded', 'states') 4.131880128431005
# ('american', 'cotton') 4.132469457568154
# ('colonial', 'union') 4.1334406424186225
# ('land', 'could') 4.134190289118207
# ('4', 'congress') 4.134551369095286
# ('industry', 'new') 4.138341212080019
# ('like', 'new') 4.138341212080019
# ('men', 'far') 4.138933186978686
# ('local', 'war') 4.140013296342109
# ('war', 'three') 4.140013296342109
# ('war', 'local') 4.140013296342109
# ('election', 'president') 4.141163979465125
# ('party', 'every') 4.1447264499651375
# ('national', 'pp') 4.148192574915079
# ('one', 'place') 4.149981409664892
# ('democrats', 'congress') 4.149981409664892
# ('state', 'popular') 4.15135084027639
# ('territory', 'united') 4.15135084027639
# ('000', 'land') 4.459473135638722
# ('life', 'one') 4.460321530277042
# ('american', 'political') 4.460852574592816
# ('convention', 'made') 4.464767435308234
# ('made', 'western') 4.464767435308234
# ('territory', 'made') 4.464767435308234
# ('act', 'trade') 4.471988474840884
# ('labor', 'vote') 4.472997920326918
# ('shall', 'vote') 4.472997920326918
# ('south', 'however') 4.473173548185299
# ('south', 'could') 4.473173548185299
# ('south', 'said') 4.473173548185299
# ('law', 'later') 4.475458658079006
# ('state', 'government') 4.477395043635984
# ('state', 'questions') 4.477395043635984
# ('states', 'legislation') 4.478055769565045
# ('policy', 'made') 4.478187951070556
# ('also', 'president') 4.479140015584357
# ('congress', 'could') 4.4796868551439735
# ('britain', 'congress') 4.4796868551439735
# ('free', 'government') 4.480172128306558
# ('revolution', 'american') 4.480392760988462
# ('two', 'political') 4.48237113684737
# ('first', 'united') 4.482556748751763
# ('south', 'became') 4.486229701010745
# ('national', 'leaders') 4.4867171803331365
# ('land', 'far') 4.487736987857443
# ('law', 'land') 4.487736987857443
# ('make', 'british') 4.488890682473813
# ('united', 'aid') 4.491200843161014
# ('events', 'united') 4.491200843161014
# ('history', 'federal') 4.491367584379245
# ('days', 'made') 4.4917344829085035
# ('spirit', 'made') 4.4917344829085035
# ('made', 'peace') 4.4917344829085035
# ('constitution', 'like') 4.494405646494931
# ('states', 'nullification') 4.494450207815714
# ...
# ('almanacs', 'calendars') 18.477042780164354
# ('seditious', 'factious') 18.477042780164354
# ('devising', 'substitutes') 18.477042780164354
# ('effectively', 'boycotted') 18.477042780164354
# ('idly', 'swinging') 18.477042780164354
# ('assertion', 'resting') 18.477042780164354
# ('riotous', 'rabble') 18.477042780164354
# ('desires', 'prudent') 18.477042780164354
# ('tidings', 'couriers') 18.477042780164354
# ('rhymes', 'satires') 18.477042780164354
# ('obscure', 'pettifogging') 18.477042780164354
# ('harlem', 'heights') 18.477042780164354
# ('coward', 'grounded') 18.477042780164354
# ('comfortable', 'bases') 18.477042780164354
# ('conway', 'cabal') 18.477042780164354
# ('minutemen', 'overwhelmed') 18.477042780164354
# ('alienated', 'fretful') 18.477042780164354
# ('engrossing', 'forestalling') 18.477042780164354
# ('silesian', 'linens') 18.477042780164354
# ('plays', 'figaro') 18.477042780164354
# ('marie', 'antoinette') 18.477042780164354
# ('fondly', 'painted') 18.477042780164354
# ('marvelous', 'tales') 18.477042780164354
# ('jacobin', 'monastery') 18.477042780164354
# ('dying', 'bird') 18.477042780164354
# ('hawk', 'eyed') 18.477042780164354
# ('restlessness', 'presaging') 18.477042780164354
# ('vanished', 'harmlessly') 18.477042780164354
# ('se', 'legally') 18.477042780164354
# ('strait', 'jacket') 18.477042780164354
# ('sonorous', 'rhetoric') 18.477042780164354
# ('scalping', 'knife') 18.477042780164354
# ('warrants', 'entitling') 18.477042780164354
# ('dying', 'intestate') 18.477042780164354
# ('entertaining', 'recollections') 18.477042780164354
# ('imaginary', 'insults') 18.477042780164354
# ('fierce', 'unsociable') 18.477042780164354
# ('eagle', 'eyed') 18.477042780164354
# ('hoosier', 'schoolmaster') 18.477042780164354
# ('tartar', 'hordes') 18.477042780164354
# ('ordains', 'creates') 18.477042780164354
# ('parish', 'constable') 18.477042780164354
# ('unseemly', 'wrangling') 18.477042780164354
# ('chancellor', 'kent') 18.477042780164354
# ('loathsome', 'creature') 18.477042780164354
# ('prim', 'farmhouses') 18.477042780164354
# ('cooking', 'stove') 18.477042780164354
# ('rio', 'grande') 18.477042780164354
# ('quaint', 'missions') 18.477042780164354
# ('moses', 'austin') 18.477042780164354
# ('barren', 'wastes') 18.477042780164354
# ('thoughtless', 'unrecorded') 18.477042780164354
# ('boulton', 'experimenting') 18.477042780164354
# ('tallow', 'candle') 18.477042780164354
# ('019', '106') 18.477042780164354
# ('housewives', 'spinsters') 18.477042780164354
# ('demagogues', 'levellers') 18.477042780164354
# ('nineteen', 'invasions') 18.477042780164354
# ('calvin', 'fairbank') 18.477042780164354
# ('eliza', 'harris') 18.477042780164354
# ('simon', 'legree') 18.477042780164354
# ('query', 'alienated') 18.477042780164354
# ('tolled', 'funeral') 18.477042780164354
# ('mercury', 'unfurled') 18.477042780164354
# ('motherless', 'calf') 18.477042780164354
# ('calf', 'bleating') 18.477042780164354
# ('entertaining', 'secessionist') 18.477042780164354
# ('stinging', 'thrusts') 18.477042780164354
# ('johnston', 'bragg') 18.477042780164354
# ('bragg', 'pemberton') 18.477042780164354
# ('pope', 'burnside') 18.477042780164354
# ('dictator', 'imperator') 18.477042780164354
# ('inns', 'theaters') 18.477042780164354
# ('weed', 'gardens') 18.477042780164354
# ('comprehensive', 'clemency') 18.477042780164354
# ('652', '654') 18.477042780164354
# ('654', '663') 18.477042780164354
# ('spanned', 'boxes') 18.477042780164354
# ('swifter', 'airplane') 18.477042780164354
# ('fastness', 'unexplored') 18.477042780164354
# ('malodorous', 'star') 18.477042780164354
# ('spiteful', 'tears') 18.477042780164354
# ('pre', 'empting') 18.477042780164354
# ('palm', 'metaphorically') 18.477042780164354
# ('ranchman', 'vanished') 18.477042780164354
# ('refine', 'ores') 18.477042780164354
# ('crude', 'sawmills') 18.477042780164354
# ('systematically', 'evaded') 18.477042780164354
# ('plural', 'marriages') 18.477042780164354
# ('towering', 'elevator') 18.477042780164354
# ('rejoice', 'thou') 18.477042780164354
# ('impending', 'fates') 18.477042780164354
# ('embittered', 'speakers') 18.477042780164354
# ('moroccan', 'bandit') 18.477042780164354
# ('caleb', 'cushing') 18.477042780164354
# ('gently', 'coerced') 18.477042780164354
# ('hundredth', 'anniversary') 18.477042780164354
# ('archduke', 'maximilian') 18.477042780164354
# ('pregnant', 'phrases') 18.477042780164354
# ('tropical', 'diseases') 18.477042780164354
# ('jacket', 'cunningly') 18.477042780164354
# ('deleterious', 'foods') 18.477042780164354
# ('dam', 'phoenix') 18.477042780164354
# ('picturing', 'fearlessly') 18.477042780164354
# ('competitive', 'examinations') 18.477042780164354
# ('chemists', 'engineers') 18.477042780164354
# ('engineers', 'architects') 18.477042780164354
# ('attractive', 'careers') 18.477042780164354
# ('extensively', 'acclaimed') 18.477042780164354
# ('expensive', 'lawsuit') 18.477042780164354
# ('contains', 'reviews') 18.477042780164354
# ('princely', 'doings') 18.477042780164354
# ('songs', 'dramas') 18.477042780164354
# ('boldest', 'thinkers') 18.477042780164354
# ('margaret', 'fuller') 18.477042780164354
# ('emma', 'willard') 18.477042780164354
# ('sisters', 'exiled') 18.477042780164354
# ('julia', 'ward') 18.477042780164354
# ('martha', 'wright') 18.477042780164354
# ('1855', 'baker') 18.477042780164354
# ('deserved', 'respectful') 18.477042780164354
# ('frances', 'willard') 18.477042780164354
# ('crass', 'inequality') 18.477042780164354
# ('sanitation', 'recreation') 18.477042780164354
# ('karl', 'marx') 18.477042780164354
# ('esch', 'cummins') 18.477042780164354
# ('countless', 'voices') 18.477042780164354
# ('47', '53') 18.477042780164354
# ('intoxicating', 'liquors') 18.477042780164354
# ('suicidal', 'commented') 18.477042780164354
# ('increasingly', 'attractive') 18.477042780164354
# ('chieftain', 'obregon') 18.477042780164354
# ('vera', 'cruz') 18.477042780164354
# ('chile', 'tendered') 18.477042780164354
# ('committing', 'robberies') 18.477042780164354
# ('alsace', 'lorraine') 18.477042780164354
# ('willfully', 'obstructed') 18.477042780164354
# ('obstructed', 'enlistment') 18.477042780164354
# ('transports', 'conveying') 18.477042780164354
# ('galling', 'artillery') 18.477042780164354
# ('zealand', 'bolivia') 18.477042780164354
# ('vittorio', 'orlando') 18.477042780164354
# ('ukraine', 'czechoslovakia') 18.477042780164354
# ('czechoslovakia', 'armenia') 18.477042780164354
# ('disorderly', 'behaviour') 18.477042780164354
# ('sundays', 'excepted') 18.477042780164354
# ('426', '861') 18.477042780164354
# ('024', '539') 18.477042780164354
# ('380', '631') 18.477042780164354
# ('404', '021') 18.477042780164354
# ('768', '014') 18.477042780164354
# ('404', '055') 18.477042780164354
# ('889', '376') 18.477042780164354
# ('376', '053') 18.477042780164354
# ('296', '372') 18.477042780164354
# ('268', '894') 18.477042780164354
# ('790', '391') 18.477042780164354
# ('069', '042') 18.477042780164354
# ('145', '965') 18.477042780164354
# ('schuyler', 'colfax') 18.477042780164354
# ('635', '426') 18.477042780164354
# ('493', '494') 18.477042780164354
# ('468ff', '495') 18.477042780164354
# ('248', '261') 18.477042780164354
# ('436ff', '559') 18.477042780164354
# ('muckraking', '536f') 18.477042780164354
# ('274', 'witchcraft') 18.477042780164354
# ('punctuation', 'normalized') 18.477042780164354
# ('normalize', 'punctuation') 18.477042780164354
# ('vanilla', 'ascii') 18.477042780164354
# ('computer', 'virus') 18.477042780164354
# ('indirect', 'consequential') 18.477042780164354
# ('alteration', 'modification') 18.477042780164354
# ('fairbanks', 'ak') 18.477042780164354
# ('director', 'gbnewby') 18.477042780164354
# ('sing', 'penitentiary') 18.629045873609403
# ('overloaded', 'curriculum') 19.477042780164354
# ('immature', 'pupil') 19.477042780164354
# ('leo', 'lentelli') 19.477042780164354
# ('lentelli', 'topped') 19.477042780164354
# ('universe', 'moves') 19.477042780164354
# ('beautifully', 'symbolic') 19.477042780164354
# ('cardinell', 'vincent') 19.477042780164354
# ('supple', 'fingers') 19.477042780164354
# ('natures', 'tuned') 19.477042780164354
# ('racial', 'strains') 19.477042780164354
# ('penns', 'carterets') 19.477042780164354
# ('pocket', 'handkerchief') 19.477042780164354
# ('humbly', 'beseech') 19.477042780164354
# ('geiser', 'redemptioners') 19.477042780164354
# ('sweet', 'wills') 19.477042780164354
# ('serges', 'kerseys') 19.477042780164354
# ('linsey', 'woolseys') 19.477042780164354
# ('coarser', 'varieties') 19.477042780164354
# ('tubal', 'cain') 19.477042780164354
# ('metallic', 'ware') 19.477042780164354
# ('ware', 'chains') 19.477042780164354
# ('chains', 'anchors') 19.477042780164354
# ('newburyport', 'salem') 19.477042780164354
# ('whale', 'fishery') 19.477042780164354
# ('amorys', 'hancocks') 19.477042780164354
# ('fearful', 'denunciations') 19.477042780164354
# ('moravians', 'lutherans') 19.477042780164354
# ('heathen', 'philosophic') 19.477042780164354
# ('apocalyptic', 'visions') 19.477042780164354
# ('sinners', 'dy') 19.477042780164354
# ('deluge', 'drown') 19.477042780164354
# ('dames', 'itinerant') 19.477042780164354
# ('academy', 'forerunner') 19.477042780164354
# ('theology', 'bunyan') 19.477042780164354
# ('courteous', 'reader') 19.477042780164354
# ('1689', '1697') 19.477042780164354
# ('felts', 'dyed') 19.477042780164354
# ('tilt', 'hammer') 19.477042780164354
# ('logic', 'unassailable') 19.477042780164354
# ('glaring', 'absurdity') 19.477042780164354
# ('absurdity', 'ascribe') 19.477042780164354
# ('hesse', 'cassel') 19.477042780164354
# ('glad', 'tidings') 19.477042780164354
# ('marston', 'moor') 19.477042780164354
# ('pettifogging', 'attorneys') 19.477042780164354
# ('anniversaries', 'celebrations') 19.477042780164354
# ('oversea', 'voyages') 19.477042780164354
# ('combatted', 'loyalist') 19.477042780164354
# ('households', 'decently') 19.477042780164354
# ('decently', 'clad') 19.477042780164354
# ('florence', 'vienna') 19.477042780164354
# ('isle', 'royale') 19.477042780164354
# ('royale', 'acadia') 19.477042780164354
# ('neglecting', 'bienséance') 19.477042780164354
# ('stiff', 'necked') 19.477042780164354
# ('weightiest', 'treatises') 19.477042780164354
# ('innate', 'goodness') 19.477042780164354
# ('profuse', 'congratulations') 19.477042780164354
# ('atheistical', 'anarchical') 19.477042780164354
# ('disturbing', 'rumor') 19.477042780164354
# ('hotch', 'potch') 19.477042780164354
# ('hornets', 'nest') 19.477042780164354
# ('cruelly', 'flogged') 19.477042780164354
# ('palpable', 'infractions') 19.477042780164354
# ('sedulously', 'cherish') 19.477042780164354
# ('discourage', 'monopolizers') 19.477042780164354
# ('foaming', 'combers') 19.477042780164354
# ('gilbert', 'imlay') 19.477042780164354
# ('abbot', 'baldwin') 19.477042780164354
# ('baldwin', 'cutler') 19.477042780164354
# ('cutler', 'huntington') 19.477042780164354
# ('huntington', 'putnam') 19.477042780164354
# ('unsociable', 'eagle') 19.477042780164354
# ('powdered', 'wigs') 19.477042780164354
# ('knee', 'breeches') 19.477042780164354
# ('breeches', 'agog') 19.477042780164354
# ('prehistoric', 'animals') 19.477042780164354
# ('connect', 'georgetown') 19.477042780164354
# ('sighed', 'carlyle') 19.477042780164354
# ('veterinarians', 'surveyors') 19.477042780164354
# ('eating', 'parched') 19.477042780164354
# ('amos', 'kendall') 19.477042780164354
# ('biter', 'bitten') 19.477042780164354
# ('quarterly', 'petulantly') 19.477042780164354
# ('superficial', 'judgments') 19.477042780164354
# ('chills', 'fevers') 19.477042780164354
# ('dubuque', 'davenport') 19.477042780164354
# ('prosaic', 'sameness') 19.477042780164354
# ('kit', 'carson') 19.477042780164354
# ('bleak', 'winters') 19.477042780164354
# ('drivers', 'pilots') 19.477042780164354
# ('commodores', 'sloat') 19.477042780164354
# ('buena', 'vista') 19.477042780164354
# ('pots', 'pans') 19.477042780164354
# ('shrewdness', 'befitting') 19.477042780164354
# ('twin', 'relics') 19.477042780164354
# ('wiseacres', 'rarely') 19.477042780164354
# ('bricklayers', 'painters') 19.477042780164354
# ('mule', 'spinners') 19.477042780164354
# ('rag', 'tag') 19.477042780164354
# ('packer', 'miller') 19.477042780164354
# ('progeny', 'drink') 19.477042780164354
# ('ichabod', 'deploring') 19.477042780164354
# ('hideous', 'distortion') 19.477042780164354
# ('cullen', 'bryant') 19.477042780164354
# ('bryant', 'ralph') 19.477042780164354
# ('ralph', 'waldo') 19.477042780164354
# ('murderous', 'gang') 19.477042780164354
# ('fanatical', 'diabolical') 19.477042780164354
# ('fireworks', 'lighted') 19.477042780164354
# ('newsboys', 'locked') 19.477042780164354
# ('sidney', 'johnston') 19.477042780164354
# ('interlines', 'exchanging') 19.477042780164354
# ('trifling', 'jobs') 19.477042780164354
# ('imperator', 'whichever') 19.477042780164354
# ('withering', 'blasts') 19.477042780164354
# ('indignities', 'wrongs') 19.477042780164354
# ('tillman', 'intend') 19.477042780164354
# ('vegetable', 'gardeners') 19.477042780164354
# ('tumbled', 'unheeded') 19.477042780164354
# ('ante', 'bellum') 19.477042780164354
# ('unparalleled', 'richness') 19.477042780164354
# ('genial', 'breeze') 19.477042780164354
# ('mercilessly', 'crushed') 19.477042780164354
# ('magyars', 'czechs') 19.477042780164354
# ('czechs', 'slovaks') 19.477042780164354
# ('slovaks', 'russians') 19.477042780164354
# ('nay', 'overcrowded') 19.477042780164354
# ('intolerably', 'impertinent') 19.477042780164354
# ('thinly', 'veiled') 19.477042780164354
# ('atchison', 'topeka') 19.477042780164354
# ('nobody', 'shoots') 19.477042780164354
# ('inspiring', 'chapters') 19.477042780164354
# ('plowmen', 'harvesters') 19.477042780164354
# ('cripple', 'creek') 19.477042780164354
# ('hotel', 'breakfast') 19.477042780164354
# ('bath', 'tubs') 19.477042780164354
# ('elevator', 'loading') 19.477042780164354
# ('bland', 'allison') 19.477042780164354
# ('unequivocal', 'indorsement') 19.477042780164354
# ('tiberius', 'gracchus') 19.477042780164354
# ('whitelaw', 'reid') 19.477042780164354
# ('nail', 'jelly') 19.477042780164354
# ('politically', 'socially') 19.477042780164354
# ('diseased', 'meats') 19.477042780164354
# ('malefactors', 'haled') 19.477042780164354
# ('steffens', 'exposed') 19.477042780164354
# ('architects', 'nurses') 19.477042780164354
# ('nurses', 'surgeons') 19.477042780164354
# ('surgeons', 'foresters') 19.477042780164354
# ('des', 'moines') 19.477042780164354
# ('akron', 'kalamazoo') 19.477042780164354
# ('laissez', 'faire') 19.477042780164354
# ('satirical', 'skits') 19.477042780164354
# ('lighthorse', 'harry') 19.477042780164354
# ('quaker', 'costume') 19.477042780164354
# ('woodson', 'farnham') 19.477042780164354
# ('farnham', 'matron') 19.477042780164354
# ('lucretia', 'mott') 19.477042780164354
# ('mott', 'martha') 19.477042780164354
# ('ann', 'mcclintock') 19.477042780164354
# ('bryn', 'mawr') 19.477042780164354
# ('heaviest', 'borrowing') 19.477042780164354
# ('austro', 'hungarian') 19.477042780164354
# ('ecuador', 'guatemala') 19.477042780164354
# ('honduras', 'liberia') 19.477042780164354
# ('finland', 'lithuania') 19.477042780164354
# ('lithuania', 'latvia') 19.477042780164354
# ('latvia', 'esthonia') 19.477042780164354
# ('esthonia', 'ukraine') 19.477042780164354
# ('arsenals', 'dock') 19.477042780164354
# ('138', '093') 19.477042780164354
# ('828', '697') 19.477042780164354
# ('939', '629') 19.477042780164354
# ('756', '908') 19.477042780164354
# ('895', '832') 19.477042780164354
# ('161', '772') 19.477042780164354
# ('821', '550') 19.477042780164354
# ('930', '390') 19.477042780164354
# ('690', '949') 19.477042780164354
# ('014', '742') 19.477042780164354
# ('720', '017') 19.477042780164354
# ('683', '724') 19.477042780164354
# ('048', '710') 19.477042780164354
# ('632', '067') 19.477042780164354
# ('hannibal', 'hamlin') 19.477042780164354
# ('358ff', '561') 19.477042780164354
# ('109ff', '238ff') 19.477042780164354
# ('238ff', '385ff') 19.477042780164354
# ('43ff', '557') 19.477042780164354
# ('347', '352ff') 19.477042780164354
# ('498f', '502ff') 19.477042780164354
# ('390ff', '401ff') 19.477042780164354
# ('401ff', '436ff') 19.477042780164354
# ('467ff', '489ff') 19.477042780164354
# ('492ff', '516ff') 19.477042780164354
# ('374ff', '385f') 19.477042780164354
# ('italicized', 'habeus') 19.477042780164354
# ('binary', 'compressed') 19.477042780164354
# ('incomplete', 'inaccurate') 19.477042780164354
# ('data', 'transcription') 19.477042780164354
# ('transcription', 'errors') 19.477042780164354
# ('damaged', 'disk') 19.477042780164354
# ('4557', 'melan') 19.477042780164354
# ('ak', '99712') 19.477042780164354
# ('ut', '84116') 19.477042780164354
# ('84116', '801') 19.477042780164354

# %%
updated_dict
# Out:
# {('As', 'things'): 2,
#  ('As', 'stand'): 1,
#  ('things', 'stand'): 2,
#  ('things', ','): 37,
#  ('stand', ','): 3,
#  ('stand', 'course'): 1,
#  (',', 'course'): 15,
#  ('course', 'instruction'): 2,
#  ('instruction', 'American'): 2,
#  ('instruction', 'history'): 1,
#  ('American', 'history'): 30,
#  ('history', 'public'): 1,
#  ('public', 'schools'): 11,
#  ('public', 'embraces'): 2,
#  ('schools', 'embraces'): 3,
#  ('public', 'three'): 1,
#  ('schools', 'three'): 2,
#  ('embraces', 'three'): 3,
#  ('schools', 'distinct'): 1,
#  ('embraces', 'distinct'): 2,
#  ('three', 'distinct'): 3,
#  ('embraces', 'treatments'): 1,
#  ('three', 'treatments'): 2,
#  ('distinct', 'treatments'): 3,
#  ('treatments', 'subject'): 1,
#  ('subject', '.'): 11,
#  ('Three', 'separate'): 1,
#  ('Three', 'books'): 1,
#  ('separate', 'books'): 2,
#  ('separate', 'used'): 1,
#  ('books', 'used'): 2,
#  ('books', '.'): 11,
#  ('used', '.'): 3,
#  ('First', ','): 7,
#  ('primary', 'book'): 3,
#  ('primary', ','): 8,
#  ('book', ','): 15,
#  (',', 'usually'): 18,
#  ('usually', 'condensed'): 1,
#  ('condensed', 'narrative'): 3,
#  ('condensed', 'emphasis'): 1,
#  ('narrative', 'emphasis'): 2,
#  ('emphasis', 'biographies'): 2,
#  ('biographies', 'anecdotes'): 2,
#  ('biographies', '.'): 1,
#  ('anecdotes', '.'): 3,
#  ('Second', ','): 1,
#  ('advanced', 'text'): 3,
#  ('text', 'seventh'): 1,
#  ('seventh', 'eighth'): 2,
#  ('seventh', 'grade'): 1,
#  ('eighth', 'grade'): 3,
#  ('eighth', ','): 2,
#  ('grade', ','): 3,
#  ('eighth', 'generally'): 1,
#  ('grade', 'generally'): 2,
#  (',', 'generally'): 16,
#  ('grade', 'speaking'): 1,
#  (',', 'speaking'): 21,
#  ('generally', 'speaking'): 3,
#  (',', ','): 5354,
#  ('generally', ','): 2,
#  ('speaking', ','): 21,
#  ('speaking', 'expansion'): 1,
#  (',', 'expansion'): 2,
#  ('expansion', 'elementary'): 1,
#  ('elementary', 'book'): 3,
#  ('book', 'addition'): 1,
#  ('addition', 'forty'): 2,
#  ('forty', 'fifty'): 2,
#  ('forty', 'thousand'): 7,
#  ('fifty', 'thousand'): 12,
#  ('fifty', 'words'): 2,
#  ('thousand', 'words'): 3,
#  ('fifty', '.'): 10,
#  ('thousand', '.'): 20,
#  ('words', '.'): 12,
#  ('Finally', ','): 12,
#  ('high', 'school'): 18,
#  ('high', 'manual'): 4,
#  ('school', 'manual'): 6,
#  ('high', '.'): 32,
#  ('school', '.'): 10,
#  ('manual', '.'): 3,
#  ('This', ','): 50,
#  (',', 'ordinarily'): 6,
#  (',', 'follows'): 4,
#  ('ordinarily', 'follows'): 3,
#  ('ordinarily', 'beaten'): 1,
#  ('follows', 'beaten'): 2,
#  ('follows', 'path'): 1,
#  ('beaten', 'path'): 3,
#  ('beaten', ','): 4,
#  ('path', ','): 4,
#  ('beaten', 'giving'): 1,
#  ('path', 'giving'): 4,
#  (',', 'giving'): 31,
#  ('path', 'fuller'): 1,
#  (',', 'fuller'): 2,
#  ('giving', 'fuller'): 3,
#  (',', 'accounts'): 3,
#  ('giving', 'accounts'): 2,
#  ('fuller', 'accounts'): 3,
#  ('events', 'characters'): 2,
#  ('events', '.'): 14,
#  ('characters', '.'): 3,
#  ('To', 'put'): 3,
#  ('To', 'bluntly'): 1,
#  ('put', 'bluntly'): 2,
#  ('put', ','): 7,
#  ('bluntly', ','): 5,
#  ('assume', 'children'): 1,
#  ('children', 'obtain'): 3,
#  ('children', 'permanent'): 2,
#  ('obtain', 'permanent'): 3,
#  ('children', 'possessions'): 1,
#  ('obtain', 'possessions'): 2,
#  ('permanent', 'possessions'): 3,
#  ('possessions', 'study'): 1,
#  ('study', 'history'): 5,
#  ('history', 'lower'): 1,
#  ('lower', 'grades'): 5,
#  ('lower', '.'): 4,
#  ('grades', '.'): 3,
#  ('If', 'mathematicians'): 1,
#  ('If', 'followed'): 1,
#  ('mathematicians', 'followed'): 2,
#  ('followed', 'method'): 1,
#  ('method', ','): 9,
#  ('method', 'high'): 2,
#  (',', 'high'): 14,
#  ('method', 'school'): 1,
#  (',', 'school'): 4,
#  (',', 'texts'): 1,
#  ('high', 'texts'): 2,
#  ('school', 'texts'): 3,
#  ('school', 'algebra'): 1,
#  ('texts', 'algebra'): 2,
#  ('algebra', 'geometry'): 2,
#  ('algebra', 'would'): 1,
#  ('geometry', 'would'): 3,
#  ('geometry', 'include'): 2,
#  ('would', 'include'): 3,
#  ('would', 'multiplication'): 1,
#  ('include', 'multiplication'): 2,
#  ('include', 'table'): 1,
#  ('multiplication', 'table'): 3,
#  ('multiplication', 'fractions'): 1,
#  ('table', 'fractions'): 2,
#  ('table', '.'): 4,
#  ('fractions', '.'): 3,
#  ('There', ','): 13,
#  ('course', ','): 38,
#  ('course', 'ready'): 1,
#  (',', 'ready'): 10,
#  (',', 'answer'): 6,
#  ('ready', 'answer'): 6,
#  ('answer', 'criticism'): 1,
#  ('criticism', 'advanced'): 3,
#  ('criticism', '.'): 4,
#  ('advanced', '.'): 11,
#  ('It', 'teachers'): 1,
#  ('teachers', 'learned'): 2,
#  ('learned', 'bitter'): 4,
#  ('learned', 'experience'): 2,
#  ('bitter', 'experience'): 9,
#  ('bitter', 'little'): 1,
#  ('experience', 'little'): 2,
#  ('experience', 'history'): 1,
#  ('little', 'history'): 3,
#  ('little', 'pupils'): 1,
#  ('history', 'pupils'): 2,
#  ('history', 'retain'): 1,
#  ('pupils', 'retain'): 3,
#  ('retain', 'pass'): 1,
#  ('pass', 'along'): 6,
#  ('pass', 'regular'): 1,
#  ('along', 'regular'): 2,
#  ('along', 'route'): 1,
#  ('regular', 'route'): 3,
#  ('regular', '.'): 10,
#  ('route', '.'): 9,
#  ('No', 'teacher'): 1,
#  ('No', 'history'): 1,
#  ('teacher', 'history'): 2,
#  ('history', 'deny'): 2,
#  ('deny', '.'): 2,
#  ('standing', 'challenge'): 3,
#  ('standing', 'existing'): 1,
#  ('challenge', 'existing'): 2,
#  ('challenge', 'methods'): 1,
#  ('existing', 'methods'): 3,
#  ('existing', 'historical'): 1,
#  ('methods', 'historical'): 2,
#  ('methods', 'instruction'): 1,
#  ('historical', 'instruction'): 3,
#  ('historical', '.'): 2,
#  ('instruction', '.'): 4,
#  ('If', 'study'): 1,
#  ('made', 'truly'): 3,
#  ('made', 'progressive'): 2,
#  ('truly', 'progressive'): 3,
#  ('made', 'like'): 1,
#  ('truly', 'like'): 2,
#  ('progressive', 'like'): 3,
#  ('progressive', 'study'): 1,
#  ('like', 'study'): 2,
#  ('study', 'mathematics'): 2,
#  ('study', ','): 3,
#  ('mathematics', ','): 4,
#  ('mathematics', 'science'): 2,
#  (',', 'science'): 10,
#  ('science', ','): 17,
#  ('science', 'languages'): 1,
#  (',', 'languages'): 2,
#  ('languages', ','): 10,
#  (',', 'historians'): 2,
#  ('historians', 'assume'): 3,
#  ('historians', 'grave'): 1,
#  ('assume', 'grave'): 2,
#  ('assume', 'responsibility'): 1,
#  ('grave', 'responsibility'): 3,
#  ('grave', 'adding'): 1,
#  ('responsibility', 'adding'): 2,
#  ('adding', 'subject'): 2,
#  ('subject', 'already'): 1,
#  ('already', 'overloaded'): 3,
#  ('already', 'curriculum'): 2,
#  ('overloaded', 'curriculum'): 3,
#  ('already', '.'): 14,
#  ('overloaded', '.'): 2,
#  ('curriculum', '.'): 3,
#  ('If', 'successive'): 1,
#  ('If', 'historical'): 1,
#  ('successive', 'historical'): 3,
#  ('successive', 'texts'): 2,
#  ('historical', 'texts'): 3,
#  ('texts', 'enlarged'): 1,
#  ('enlarged', 'editions'): 3,
#  ('editions', 'first'): 1,
#  ('first', 'text'): 4,
#  ('first', '--'): 4,
#  ('text', '--'): 3,
#  ('text', 'facts'): 1,
#  ('--', 'facts'): 2,
#  ('--', ','): 440,
#  ('facts', ','): 6,
#  ('facts', 'dates'): 1,
#  (',', 'dates'): 2,
#  ('dates', ','): 3,
#  ('dates', 'words'): 1,
#  (',', 'words'): 6,
#  (',', '--'): 104,
#  ('words', '--'): 3,
#  ('words', 'history'): 1,
#  ('--', 'history'): 2,
#  ('--', 'deserves'): 1,
#  ('history', 'deserves'): 3,
#  ('sharp', 'criticism'): 6,
#  ('receiving', 'teachers'): 2,
#  ('teachers', 'science'): 2,
#  ('teachers', ','): 14,
#  ('science', 'civics'): 2,
#  (',', 'civics'): 3,
#  ('civics', ','): 3,
#  ('civics', 'economics'): 1,
#  (',', 'economics'): 2,
#  (',', '.'): 1553,
#  ('economics', '.'): 3,
#  ('In', 'condition'): 1,
#  ('condition', 'affairs'): 4,
#  ('affairs', 'find'): 2,
#  ('find', 'justification'): 2,
#  ('justification', 'offering'): 2,
#  ('offering', 'new'): 2,
#  ('offering', 'high'): 1,
#  ('new', 'high'): 3,
#  ('new', 'school'): 4,
#  ('new', 'text'): 1,
#  ('high', 'text'): 2,
#  ('school', 'text'): 3,
#  ('school', 'American'): 1,
#  ('text', 'American'): 2,
#  ('text', 'history'): 1,
#  ('American', '.'): 247,
#  ('history', '.'): 48,
#  ('Our', 'first'): 1,
#  ('Our', 'contribution'): 1,
#  ('first', 'contribution'): 2,
#  ('first', 'one'): 5,
#  ('contribution', 'one'): 2,
#  ('one', 'omission'): 2,
#  ('one', '.'): 87,
#  ('omission', '.'): 3,
#  ('The', 'time-honored'): 1,
#  ('The', 'stories'): 1,
#  ('time-honored', 'stories'): 2,
#  ('time-honored', 'exploration'): 1,
#  ('stories', 'exploration'): 2,
#  ('exploration', 'biographies'): 1,
#  ('biographies', 'heroes'): 2,
#  ('heroes', 'left'): 2,
#  ('left', '.'): 6,
#  ('We', 'frankly'): 1,
#  ('We', 'hold'): 1,
#  ('frankly', 'hold'): 2,
#  ('frankly', ','): 1,
#  ('hold', ','): 10,
#  (',', 'pupils'): 2,
#  (',', 'know'): 4,
#  ('pupils', 'know'): 3,
#  ('pupils', 'little'): 2,
#  ('know', 'little'): 6,
#  ('know', 'nothing'): 1,
#  ('little', 'nothing'): 2,
#  ('nothing', 'Columbus'): 2,
#  ('nothing', ','): 1,
#  ('Columbus', ','): 11,
#  ('Columbus', 'Cortes'): 2,
#  (',', 'Cortes'): 3,
#  ('Cortes', ','): 4,
#  (',', 'Magellan'): 4,
#  ('Cortes', 'Magellan'): 2,
#  ('Magellan', ','): 6,
#  ('Magellan', 'Captain'): 1,
#  (',', 'Captain'): 15,
#  (',', 'John'): 129,
#  ('Captain', 'John'): 9,
#  ('Captain', 'Smith'): 4,
#  ('John', 'Smith'): 9,
#  ('Smith', 'time'): 1,
#  ('time', 'reach'): 2,
#  ('reach', 'high'): 2,
#  ('reach', 'school'): 1,
#  ('high', ','): 27,
#  ('school', ','): 12,
#  (',', 'useless'): 2,
#  ('useless', 'tell'): 2,
#  ('tell', 'stories'): 1,
#  ('stories', 'perhaps'): 2,
#  ('perhaps', 'fourth'): 2,
#  ('perhaps', 'time'): 1,
#  ('fourth', 'time'): 3,
#  ('fourth', '.'): 2,
#  ('time', '.'): 91,
#  ('It', 'worse'): 1,
#  ('worse', 'useless'): 2,
#  ('worse', '.'): 4,
#  ('useless', '.'): 6,
#  ('It', 'offense'): 1,
#  ('offense', 'teachers'): 1,
#  ('teachers', 'subjects'): 1,
#  ('subjects', 'demonstrated'): 1,
#  ('demonstrated', 'progressive'): 1,
#  ('progressive', 'character'): 2,
#  ('progressive', '.'): 5,
#  ('character', '.'): 32,
#  ('In', 'next'): 1,
#  ('In', 'place'): 30,
#  ('next', 'place'): 3,
#  ('place', 'omitted'): 1,
#  ('omitted', 'descriptions'): 2,
#  ('descriptions', 'battles'): 2,
#  ('descriptions', '.'): 1,
#  ('battles', '.'): 3,
#  ('Our', 'reasons'): 1,
#  ('simple', '.'): 24,
#  ('The', 'strategy'): 1,
#  ('strategy', 'campaign'): 1,
#  ('single', 'battle'): 5,
#  ('battle', 'highly'): 1,
#  ('highly', 'technical'): 3,
#  ('highly', ','): 4,
#  ('technical', ','): 9,
#  ('technical', 'usually'): 1,
#  ('usually', 'highly'): 2,
#  ('usually', 'controversial'): 1,
#  ('highly', 'controversial'): 3,
#  ('controversial', ','): 3,
#  ('highly', 'matter'): 1,
#  ('controversial', 'matter'): 2,
#  (',', 'matter'): 19,
#  ('matter', 'experts'): 1,
#  ('experts', 'differ'): 3,
#  ('experts', 'widely'): 2,
#  ('differ', 'widely'): 3,
#  ('experts', '.'): 1,
#  ('differ', '.'): 2,
#  ('widely', '.'): 15,
#  ('In', 'field'): 7,
#  ('field', 'military'): 2,
#  ('military', 'naval'): 20,
#  ('military', 'operations'): 7,
#  ('naval', 'operations'): 3,
#  ('naval', 'writers'): 1,
#  ('operations', 'writers'): 2,
#  ('writers', 'teachers'): 2,
#  ('teachers', 'history'): 2,
#  ('history', 'mere'): 2,
#  ('history', 'novices'): 1,
#  ('mere', 'novices'): 3,
#  ('mere', '.'): 6,
#  ('novices', '.'): 3,
#  ('To', 'dispose'): 1,
#  ('To', 'Gettysburg'): 1,
#  ('dispose', 'Gettysburg'): 2,
#  ('Gettysburg', 'Wilderness'): 1,
#  ('Wilderness', 'ten'): 2,
#  ('Wilderness', 'lines'): 1,
#  ('ten', 'lines'): 3,
#  ('ten', 'ten'): 1,
#  ('lines', 'ten'): 2,
#  ('lines', 'pages'): 1,
#  ('ten', 'pages'): 3,
#  ('ten', 'equally'): 1,
#  ('pages', 'equally'): 2,
#  ('pages', 'absurd'): 1,
#  ('equally', 'absurd'): 3,
#  ('absurd', 'serious'): 1,
#  ('serious', 'student'): 3,
#  ('serious', 'military'): 1,
#  ('student', 'military'): 2,
#  ('student', 'affairs'): 1,
#  ('military', 'affairs'): 12,
#  ('military', '.'): 37,
#  ('affairs', '.'): 57,
#  ('Any', 'one'): 2,
#  ('Any', 'compares'): 1,
#  ('one', 'compares'): 2,
#  ('compares', 'ordinary'): 2,
#  ('compares', 'textbook'): 1,
#  ('ordinary', 'textbook'): 3,
#  ('ordinary', 'account'): 2,
#  ('textbook', 'account'): 3,
#  ('account', 'single'): 1,
#  ('single', 'Civil'): 3,
#  ('single', 'War'): 2,
#  ('Civil', 'War'): 211,
#  ('single', 'campaign'): 1,
#  ('Civil', 'campaign'): 2,
#  ('War', 'campaign'): 3,
#  ('campaign', 'account'): 1,
#  ('account', 'given'): 3,
#  ('account', 'Ropes'): 1,
#  ('given', 'Ropes'): 2,
#  ('given', ','): 13,
#  ('Ropes', ','): 5,
#  ('Ropes', 'instance'): 1,
#  (',', 'instance'): 17,
#  ('instance', ','): 32,
#  ('instance', 'ask'): 1,
#  (',', 'ask'): 2,
#  ('comment', '.'): 7,
#  ('No', 'youth'): 1,
#  ('No', 'called'): 2,
#  ('No', 'upon'): 1,
#  ('youth', 'called'): 2,
#  ('youth', 'upon'): 2,
#  ('called', 'upon'): 52,
#  ('called', 'serve'): 1,
#  ('upon', 'serve'): 2,
#  ('serve', 'country'): 2,
#  ('country', 'arms'): 2,
#  ('country', 'would'): 1,
#  ('arms', 'would'): 3,
#  ('arms', 'think'): 2,
#  ('would', 'think'): 4,
#  ('would', 'turning'): 1,
#  ('think', 'turning'): 2,
#  ('turning', 'high'): 1,
#  ('school', 'information'): 1,
#  ('manual', 'information'): 2,
#  ('information', 'art'): 1,
#  ('art', 'warfare'): 4,
#  ('art', '.'): 2,
#  ('warfare', '.'): 18,
#  ('The', 'dramatic'): 1,
#  ('The', 'scene'): 2,
#  ('dramatic', 'scene'): 2,
#  ('dramatic', 'episode'): 1,
#  ('scene', 'episode'): 2,
#  ('scene', ','): 13,
#  ('episode', ','): 3,
#  ('episode', 'useful'): 1,
#  (',', 'useful'): 4,
#  ('useful', 'arousing'): 2,
#  ('arousing', 'interest'): 4,
#  ('interest', 'immature'): 1,
#  ('immature', 'pupil'): 3,
#  ('immature', ','): 2,
#  ('pupil', ','): 3,
#  ('immature', 'seems'): 1,
#  ('pupil', 'seems'): 2,
#  (',', 'seems'): 16,
#  ('seems', 'place'): 1,
#  ('place', 'book'): 1,
#  ('book', 'deliberately'): 2,
#  ('book', 'appeals'): 1,
#  ('deliberately', 'appeals'): 3,
#  ('deliberately', 'boys'): 1,
#  ('appeals', 'boys'): 2,
#  ('boys', 'girls'): 4,
#  ('threshold', 'life'): 2,
#  ('threshold', "'s"): 1,
#  ('life', "'s"): 6,
#  ('life', 'serious'): 2,
#  ("'s", 'serious'): 3,
#  ('life', 'responsibilities'): 1,
#  ("'s", 'responsibilities'): 2,
#  ('serious', 'responsibilities'): 3,
#  ("'s", '.'): 100,
#  ('serious', '.'): 8,
#  ('responsibilities', '.'): 3,
#  ('It', 'upon'): 7,
#  ('upon', 'negative'): 3,
#  ('upon', 'features'): 4,
#  ('negative', 'features'): 3,
#  ('upon', ','): 47,
#  ('negative', ','): 2,
#  ('features', ','): 4,
#  ('negative', 'however'): 1,
#  ('features', 'however'): 2,
#  (',', 'however'): 319,
#  ('however', ','): 315,
#  (',', 'rest'): 8,
#  ('rest', 'case'): 4,
#  ('rest', '.'): 18,
#  ('case', '.'): 22,
#  ('It', 'rather'): 1,
#  ('rather', 'upon'): 3,
#  ('rather', 'constructive'): 2,
#  ('upon', 'constructive'): 3,
#  ('rather', 'features'): 1,
#  ('constructive', 'features'): 3,
#  ('upon', '.'): 71,
#  ('constructive', '.'): 2,
#  ('features', '.'): 15,
#  ('_First._', 'We'): 1,
#  ('_First._', 'written'): 1,
#  ('We', 'written'): 2,
#  ('written', 'topical'): 2,
#  ('written', ','): 2,
#  ('topical', ','): 5,
#  (',', 'narrative'): 1,
#  ('narrative', ','): 3,
#  ('narrative', 'history'): 2,
#  (',', 'history'): 5,
#  ('narrative', '.'): 1,
#  ('We', 'tried'): 1,
#  ('tried', 'set'): 2,
#  ('tried', 'forth'): 1,
#  ('set', 'forth'): 57,
#  ('set', 'important'): 1,
#  ('forth', 'important'): 2,
#  ('forth', 'aspects'): 1,
#  ('important', 'aspects'): 3,
#  ('important', ','): 11,
#  ('aspects', ','): 7,
#  ('important', 'problems'): 1,
#  ('aspects', 'problems'): 2,
#  (',', 'problems'): 7,
#  ('problems', ','): 14,
#  ('problems', 'movements'): 1,
#  (',', 'movements'): 2,
#  ('movements', 'period'): 1,
#  ('period', ','): 36,
#  ('period', 'bringing'): 2,
#  (',', 'bringing'): 6,
#  ('bringing', 'narrative'): 1,
#  ('narrative', 'rather'): 3,
#  ('narrative', 'way'): 1,
#  ('rather', 'way'): 2,
#  ('way', 'illustration'): 2,
#  ('way', '.'): 33,
#  ('illustration', '.'): 6,
#  ('_Second._', 'We'): 1,
#  ('_Second._', 'emphasized'): 1,
#  ('We', 'emphasized'): 2,
#  ('emphasized', 'historical'): 2,
#  ('emphasized', 'topics'): 1,
#  ('historical', 'topics'): 3,
#  ('historical', 'help'): 1,
#  ('topics', 'help'): 2,
#  ('help', 'explain'): 2,
#  ('explain', 'nation'): 1,
#  ('nation', 'come'): 2,
#  ('to-day', '.'): 9,
#  ('_Third._', 'We'): 1,
#  ('_Third._', 'dwelt'): 1,
#  ('We', 'dwelt'): 2,
#  ('We', 'fully'): 1,
#  ('dwelt', 'fully'): 3,
#  ('dwelt', 'upon'): 5,
#  ('fully', 'upon'): 3,
#  ('fully', 'social'): 1,
#  ('upon', 'social'): 5,
#  ('social', 'economic'): 2,
#  ('social', 'aspects'): 1,
#  ('economic', 'aspects'): 9,
#  ('aspects', 'history'): 1,
#  ('history', ','): 24,
#  ('history', 'especially'): 2,
#  (',', 'especially'): 89,
#  (',', 'relation'): 3,
#  ('especially', 'relation'): 4,
#  ('relation', 'politics'): 1,
#  ('politics', 'period'): 2,
#  ('period', '.'): 14,
#  ('_Fourth._', 'We'): 1,
#  ('_Fourth._', 'treated'): 1,
#  ('We', 'treated'): 2,
#  ('treated', 'causes'): 2,
#  ('causes', 'results'): 2,
#  ('results', 'wars'): 3,
#  ('results', ','): 9,
#  ('wars', ','): 32,
#  ('wars', 'problems'): 1,
#  ('problems', 'financing'): 2,
#  ('financing', 'sustaining'): 2,
#  ('financing', 'armed'): 1,
#  ('sustaining', 'armed'): 3,
#  ('sustaining', 'forces'): 2,
#  ('armed', 'forces'): 18,
#  ('sustaining', ','): 1,
#  ('armed', ','): 19,
#  ('forces', ','): 26,
#  ('armed', 'rather'): 1,
#  ('forces', 'rather'): 2,
#  (',', 'rather'): 41,
#  (',', 'military'): 25,
#  ('rather', 'military'): 2,
#  ('rather', 'strategy'): 1,
#  ('military', 'strategy'): 9,
#  ('strategy', '.'): 3,
#  ('These', 'subjects'): 1,
#  ('subjects', 'belong'): 2,
#  ('belong', 'history'): 1,
#  ('history', 'civilians'): 2,
#  ('civilians', '.'): 3,
#  ('These', 'matters'): 1,
#  ('matters', 'civilians'): 2,
#  ('civilians', 'understand'): 2,
#  ('civilians', '--'): 1,
#  ('understand', '--'): 3,
#  ('understand', 'matters'): 2,
#  ('--', 'matters'): 4,
#  ('matters', 'must'): 1,
#  ('must', 'understand'): 3,
#  ('must', ','): 16,
#  ('understand', ','): 8,
#  ('play', 'well'): 3,
#  ('play', 'part'): 3,
#  ('well', 'part'): 4,
#  ('part', 'war'): 2,
#  ('war', 'peace'): 5,
#  ('war', '.'): 176,
#  ('peace', '.'): 39,
#  ('_Fifth._', 'By'): 1,
#  ('_Fifth._', 'omitting'): 1,
#  ('By', 'omitting'): 2,
#  ('By', 'period'): 1,
#  ('omitting', 'period'): 2,
#  ('period', 'exploration'): 2,
#  ('exploration', ','): 4,
#  ('able', 'enlarge'): 2,
#  ('enlarge', 'treatment'): 2,
#  ('We', 'given'): 1,
#  ('We', 'special'): 1,
#  ('given', 'special'): 3,
#  ('given', 'attention'): 2,
#  ('special', 'attention'): 3,
#  ('attention', 'history'): 1,
#  ('history', 'current'): 1,
#  ('current', 'questions'): 3,
#  ('current', 'must'): 1,
#  ('questions', 'must'): 2,
#  ('questions', 'form'): 1,
#  ('must', 'form'): 3,
#  ('must', 'subject'): 1,
#  ('form', 'subject'): 2,
#  ('form', 'matter'): 1,
#  ('subject', 'matter'): 3,
#  ('subject', 'sound'): 1,
#  ('matter', 'sound'): 2,
#  ('matter', 'instruction'): 1,
#  ('sound', 'instruction'): 3,
#  ('sound', 'citizenship'): 1,
#  ('instruction', 'citizenship'): 2,
#  ('citizenship', '.'): 11,
#  ('_Sixth._', 'We'): 1,
#  ('_Sixth._', 'borne'): 1,
#  ('We', 'borne'): 2,
#  ('borne', 'mind'): 2,
#  ('mind', 'America'): 2,
#  ('mind', ','): 9,
#  ('America', ','): 136,
#  ('unique', 'characteristics'): 3,
#  ('unique', ','): 2,
#  ('characteristics', ','): 3,
#  (',', 'part'): 17,
#  ('part', 'general'): 1,
#  ('general', 'civilization'): 3,
#  ('general', '.'): 38,
#  ('civilization', '.'): 21,
#  ('Accordingly', 'given'): 1,
#  ('given', 'diplomacy'): 3,
#  ('diplomacy', ','): 16,
#  ('given', 'foreign'): 1,
#  ('diplomacy', 'foreign'): 2,
#  (',', 'foreign'): 32,
#  ('diplomacy', 'affairs'): 1,
#  (',', 'affairs'): 6,
#  ('foreign', 'affairs'): 9,
#  ('foreign', ','): 44,
#  ('affairs', ','): 41,
#  ('foreign', 'world'): 4,
#  ('affairs', 'world'): 2,
#  (',', 'world'): 7,
#  ('affairs', 'relations'): 1,
#  (',', 'relations'): 11,
#  ('world', 'relations'): 3,
#  ('world', ','): 27,
#  ('relations', ','): 17,
#  (',', 'reciprocal'): 1,
#  ('reciprocal', 'influences'): 3,
#  ('reciprocal', 'nations'): 1,
#  ('influences', 'nations'): 2,
#  ('nations', 'appropriate'): 2,
#  ('nations', 'place'): 1,
#  ('appropriate', 'place'): 3,
#  ('appropriate', '.'): 14,
#  ('place', '.'): 18,
#  ('_Seventh._', 'We'): 1,
#  ('_Seventh._', 'deliberately'): 1,
#  ('We', 'deliberately'): 2,
#  ('We', 'aimed'): 2,
#  ('deliberately', 'aimed'): 6,
#  ('deliberately', 'standards'): 1,
#  ('aimed', 'standards'): 2,
#  ('standards', 'maturity'): 2,
#  ('standards', '.'): 1,
#  ('maturity', '.'): 4,
#  ('The', 'study'): 1,
#  ('study', 'mere'): 1,
#  ('mere', 'narrative'): 3,
#  ('mere', 'calls'): 2,
#  ('narrative', 'calls'): 3,
#  ('mere', 'mainly'): 1,
#  ('narrative', 'mainly'): 2,
#  ('calls', 'mainly'): 3,
#  ('mainly', 'use'): 1,
#  ('use', 'memory'): 1,
#  ('memory', '.'): 5,
#  ('aimed', 'stimulate'): 2,
#  ('aimed', 'habits'): 1,
#  ('stimulate', 'habits'): 3,
#  ('stimulate', 'analysis'): 1,
#  ('habits', 'analysis'): 2,
#  ('habits', ','): 10,
#  ('analysis', ','): 4,
#  ('analysis', 'comparison'): 2,
#  (',', 'comparison'): 3,
#  ('comparison', ','): 10,
#  (',', 'association'): 11,
#  ('comparison', 'association'): 2,
#  ('association', ','): 13,
#  (',', 'reflection'): 4,
#  ('association', 'reflection'): 2,
#  ('reflection', ','): 3,
#  ('reflection', 'generalization'): 1,
#  (',', 'generalization'): 2,
#  ('generalization', '--'): 3,
#  ('generalization', 'habits'): 2,
#  ('--', 'habits'): 3,
#  ('generalization', 'calculated'): 1,
#  ('--', 'calculated'): 2,
#  ('habits', 'calculated'): 3,
#  ('habits', 'enlarge'): 1,
#  ('calculated', 'enlarge'): 2,
#  ('enlarge', 'well'): 2,
#  ('well', 'inform'): 2,
#  ('inform', 'mind'): 2,
#  ('inform', '.'): 1,
#  ('mind', '.'): 21,
#  ('great', 'pains'): 3,
#  ('great', 'make'): 2,
#  ('pains', 'make'): 2,
#  ('make', 'text'): 2,
#  ('make', 'clear'): 1,
#  ('text', 'clear'): 3,
#  ('text', ','): 3,
#  ('clear', ','): 14,
#  ('text', 'simple'): 1,
#  ('clear', 'simple'): 4,
#  (',', 'simple'): 9,
#  ('simple', ','): 16,
#  ('simple', 'direct'): 1,
#  (',', 'direct'): 21,
#  (',', ';'): 77,
#  ('direct', ';'): 4,
#  ('earnestly', 'sought'): 6,
#  ('earnestly', 'stretch'): 1,
#  ('sought', 'stretch'): 2,
#  ('stretch', 'intellects'): 2,
#  ('intellects', 'readers'): 1,
#  ('readers', '--'): 3,
#  ('readers', 'put'): 1,
#  ('--', 'put'): 2,
#  ('put', 'upon'): 9,
#  ('upon', 'mettle'): 2,
#  ('mettle', '.'): 3,
#  ('receive', 'last'): 2,
#  ('last', 'formal'): 1,
#  ('formal', 'instruction'): 3,
#  ('instruction', 'high'): 1,
#  ('The', 'world'): 4,
#  ('The', 'soon'): 1,
#  ('world', 'soon'): 2,
#  ('world', 'expect'): 1,
#  ('soon', 'expect'): 3,
#  ('soon', 'maturity'): 2,
#  ('expect', 'maturity'): 3,
#  ('Their', 'achievements'): 1,
#  ('Their', 'depend'): 1,
#  ('achievements', 'depend'): 2,
#  ('achievements', 'upon'): 1,
#  ('depend', 'upon'): 6,
#  ('depend', 'possession'): 1,
#  ('upon', 'possession'): 2,
#  ('possession', 'powers'): 1,
#  ('powers', 'memory'): 2,
#  ('powers', 'alone'): 1,
#  ('memory', 'alone'): 3,
#  ('alone', '.'): 27,
#  ('The', 'effectiveness'): 1,
#  ('effectiveness', 'citizenship'): 1,
#  ('citizenship', 'republic'): 1,
#  ('republic', 'measured'): 1,
#  ('measured', 'excellence'): 1,
#  ('excellence', 'judgment'): 1,
#  ('judgment', 'well'): 2,
#  ('well', 'fullness'): 1,
#  ('fullness', 'information'): 1,
#  ('information', '.'): 3,
#  ('C.A.B', '.'): 1,
#  ('M.R.B', '.'): 1,
#  ('NEW', 'YORK'): 13,
#  ('NEW', 'CITY'): 7,
#  ('NEW', ','): 1,
#  ('YORK', 'CITY'): 11,
#  ('YORK', ','): 2,
#  ('CITY', ','): 3,
#  ('YORK', 'February'): 1,
#  ('CITY', 'February'): 2,
#  (',', 'February'): 11,
#  ('CITY', '8'): 1,
#  (',', '8'): 2,
#  ('February', '8'): 6,
#  ('February', ','): 72,
#  ('8', ','): 20,
#  ('February', '1921'): 1,
#  ('8', '1921'): 2,
#  (',', '1921'): 3,
#  ('8', '.'): 35,
#  ('1921', '.'): 3,
#  ('=A', 'SMALL'): 1,
#  ('=A', 'LIBRARY'): 1,
#  ('=A', 'IN'): 1,
#  ('SMALL', 'LIBRARY'): 2,
#  ('SMALL', 'IN'): 2,
#  ('LIBRARY', 'IN'): 3,
#  ('SMALL', 'AMERICAN'): 1,
#  ('LIBRARY', 'AMERICAN'): 2,
#  ('IN', 'AMERICAN'): 3,
#  ('LIBRARY', 'HISTORY='): 1,
#  ('IN', 'HISTORY='): 2,
#  ('AMERICAN', 'HISTORY='): 3,
#  ('IN', '_=SINGLE'): 1,
#  ('AMERICAN', '_=SINGLE'): 2,
#  ('HISTORY=', '_=SINGLE'): 3,
#  ('AMERICAN', 'VOLUMES'): 1,
#  ('HISTORY=', 'VOLUMES'): 2,
#  ('_=SINGLE', 'VOLUMES'): 3,
#  ('HISTORY=', ':'): 1,
#  ('_=SINGLE', ':'): 2,
#  ('VOLUMES', ':'): 3,
#  ('_=SINGLE', '=_'): 1,
#  ('VOLUMES', '=_'): 2,
#  (':', '=_'): 6,
#  ('VOLUMES', 'BASSETT'): 1,
#  (':', 'BASSETT'): 2,
#  ('=_', 'BASSETT'): 3,
#  (':', ','): 147,
#  ('=_', ','): 2,
#  ('BASSETT', ','): 3,
#  ('=_', 'J.S'): 1,
#  ('BASSETT', 'J.S'): 2,
#  (',', 'J.S'): 3,
#  ('BASSETT', '.'): 1,
#  ('J.S', '.'): 9,
#  ('_A', 'Short'): 1,
#  ('_A', 'History'): 9,
#  ('Short', 'History'): 2,
#  ('History', 'United'): 24,
#  ('United', 'States_'): 213,
#  ('United', 'ELSON'): 2,
#  ('States_', 'ELSON'): 3,
#  ('United', ','): 256,
#  ('States_', ','): 158,
#  ('ELSON', ','): 3,
#  ('States_', 'H.W'): 1,
#  ('ELSON', 'H.W'): 2,
#  (',', 'H.W'): 5,
#  ('ELSON', '.'): 1,
#  ('H.W', '.'): 8,
#  ('_History', 'United'): 31,
#  ('United', 'States'): 1159,
#  ('United', 'America_'): 1,
#  ('States', 'America_'): 3,
#  ('States', '_=SERIES'): 1,
#  ('America_', '_=SERIES'): 3,
#  ('America_', ':'): 2,
#  ('_=SERIES', ':'): 3,
#  ('America_', '=_'): 1,
#  ('_=SERIES', '=_'): 2,
#  ('_=SERIES', '``'): 1,
#  (':', '``'): 336,
#  ('=_', '``'): 3,
#  (':', 'EPOCHS'): 1,
#  ('=_', 'EPOCHS'): 2,
#  ('``', 'EPOCHS'): 3,
#  ('=_', 'OF'): 1,
#  ('``', 'OF'): 4,
#  ('EPOCHS', 'OF'): 3,
#  ('``', 'AMERICAN'): 1,
#  ('EPOCHS', 'AMERICAN'): 2,
#  ('OF', 'AMERICAN'): 9,
#  ('EPOCHS', 'HISTORY'): 1,
#  ('OF', 'HISTORY'): 2,
#  ('AMERICAN', 'HISTORY'): 3,
#  ('OF', ','): 9,
#  ('AMERICAN', ','): 2,
#  ('HISTORY', ','): 3,
#  ('AMERICAN', "''"): 1,
#  ('HISTORY', "''"): 2,
#  (',', "''"): 944,
#  ('HISTORY', 'EDITED'): 1,
#  (',', 'EDITED'): 4,
#  ("''", 'EDITED'): 6,
#  (',', 'BY'): 5,
#  ("''", 'BY'): 4,
#  ('EDITED', 'BY'): 6,
#  ("''", 'A.B'): 1,
#  ('EDITED', 'A.B'): 2,
#  ('BY', 'A.B'): 3,
#  ('EDITED', '.'): 2,
#  ('BY', '.'): 4,
#  ('A.B', '.'): 14,
#  ('HART', 'HART'): 1,
#  ('HART', ','): 3,
#  ('HART', 'A.B'): 3,
#  (',', 'A.B'): 3,
#  ('HART', '.'): 1,
#  ('_Formation', 'Union_'): 1,
#  ('Union_', 'THWAITES'): 3,
#  ('Union_', ','): 2,
#  ('THWAITES', ','): 3,
#  ('Union_', 'R.G'): 1,
#  ('THWAITES', 'R.G'): 2,
#  (',', 'R.G'): 3,
#  ('THWAITES', '.'): 1,
#  ('R.G', '.'): 6,
#  ('_The', 'Colonies_'): 1,
#  ('_The', 'WILSON'): 1,
#  ('_The', ','): 11,
#  ('Colonies_', 'WILSON'): 2,
#  ('Colonies_', ','): 5,
#  ('WILSON', ','): 3,
#  ('Colonies_', 'WOODROW'): 1,
#  ('WILSON', 'WOODROW'): 2,
#  (',', 'WOODROW'): 3,
#  ('WILSON', '.'): 1,
#  ('WOODROW', '.'): 3,
#  ('_Division', 'Reunion_'): 1,
#  ('_Division', '``'): 1,
#  ('Reunion_', '``'): 3,
#  ('Reunion_', 'RIVERSIDE'): 2,
#  ('``', 'RIVERSIDE'): 3,
#  ('Reunion_', 'SERIES'): 1,
#  ('``', 'SERIES'): 2,
#  ('RIVERSIDE', 'SERIES'): 3,
#  ('``', ','): 196,
#  ('RIVERSIDE', ','): 2,
#  ('SERIES', ','): 3,
#  ('RIVERSIDE', "''"): 1,
#  ('SERIES', "''"): 2,
#  ('SERIES', 'EDITED'): 1,
#  ("''", 'W.E'): 1,
#  ('EDITED', 'W.E'): 2,
#  ('BY', 'W.E'): 3,
#  ...}
