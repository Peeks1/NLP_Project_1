# %%
import nltk
import math
from itertools import combinations
from nltk.corpus import stopwords
import string

# %%
file_name = "text.txt"
val = {}
def file_reading(file_name):
    file = open(file_name).read()
    word = nltk.word_tokenize(file)
    file.close()
    return word

# %%
def unigram_counting(text):
    unigram = nltk.ngrams(text,1)
    unigram_list = [ ' '.join(grams) for grams in unigram]
    unigram_count = len(unigram_list)
    return unigram_count

# %%
def collocation_calculator(file_name):
    file = open(file_name).read()
    sentences = nltk.sent_tokenize(file)
    new_list = []
    word_dict = {}
    for i in range (len(sentences)):
        s = ' '.join(sentences[i].split('\n'))
        table = str.maketrans((string.punctuation),' '*len(string.punctuation)) 
        new_s = s.translate(table) 
        new_list.append(new_s) 
    collacations_counter ={}
    for i in range(len(new_list)):
        counter = 0
        word = nltk.word_tokenize(new_list[i])
        for index in range(len(word)):
            if word[index] in word_dict:
                word_dict[word[index]]+=1
            else:
                word_dict[word[index]]=1
            if len(word[index:index+4]) != 1:
                sub_list = combinations(word[index:index+4],2)
                for item in sub_list:
                    if item in collacations_counter:
                        collacations_counter[item] +=1
                    else:
                        collacations_counter[item] =1
    stoplist = stopwords.words('english')
    for i in collacations_counter:
        for j in stoplist:
            if j in i:
                collacations_counter[i] = None
    updated_dict = {}
    for i in collacations_counter:
        if collacations_counter[i]!= None:
            updated_dict[i]= collacations_counter[i]
    return updated_dict,word_dict

# %%
text = file_reading(file_name)
size = unigram_counting(text)
val,word_count = collocation_calculator(file_name)

def pointwise_mutual_information(size,collocation_count,word_count):
    PMI = {}
    for i in collocation_count:
        word_1 = i[0]
        word_2 = i[1]
        PMI[i] = math.log2(size*((collocation_count[i])/(word_count[word_1]*word_count[word_2])))
        
    return PMI

# %%
PMI = pointwise_mutual_information(size,val,word_count)

# %%
PMI
# Out:
# {('As', 'things'): 6.042870678873935,
#  ('As', 'stand'): 6.509996689301232,
#  ('things', 'stand'): 9.250028586515223,
#  ('stand', 'course'): 8.296822797994164,
#  ('course', 'instruction'): 9.799323138523347,
#  ('instruction', 'American'): 6.78944839058823,
#  ('instruction', 'history'): 8.914800355943282,
#  ('American', 'history'): 6.888984064139145,
#  ('history', 'public'): 3.827337514692943,
#  ('public', 'schools'): 9.772195960500481,
#  ('public', 'embraces'): 10.219654937471702,
#  ('schools', 'embraces'): 14.570152184555836,
#  ('public', 'three'): 3.277140432132463,
#  ('schools', 'three'): 8.04267517849544,
#  ('embraces', 'three'): 11.534528274825115,
#  ('schools', 'distinct'): 10.284749965693589,
#  ('embraces', 'distinct'): 14.191640561302107,
#  ('three', 'distinct'): 8.834088556684023,
#  ('embraces', 'treatments'): 16.8920802794432,
#  ('three', 'treatments'): 11.94956577410396,
#  ('distinct', 'treatments'): 15.776603062023263,
#  ('treatments', 'subject'): 12.034099284315626,
#  ('Three', 'separate'): 9.561163401328582,
#  ('Three', 'books'): 9.368518323386185,
#  ('separate', 'books'): 11.084725357385594,
#  ('separate', 'used'): 9.177834761777076,
#  ('books', 'used'): 9.98518968383468,
#  ('primary', 'book'): 12.400227183113524,
#  ('book', 'usually'): 9.59287226105592,
#  ('usually', 'condensed'): 13.499762856664438,
#  ('condensed', 'narrative'): 16.8920802794432,
#  ('condensed', 'emphasis'): 16.8920802794432,
#  ('narrative', 'emphasis'): 15.307117778722043,
#  ('emphasis', 'biographies'): 16.8920802794432,
#  ('biographies', 'anecdotes'): 17.8920802794432,
#  ('advanced', 'text'): 11.159630166399486,
#  ('text', 'seventh'): 14.432648660805901,
#  ('seventh', 'eighth'): 18.8920802794432,
#  ('seventh', 'grade'): 16.30711777872204,
#  ('eighth', 'grade'): 17.8920802794432,
#  ('eighth', 'generally'): 14.570152184555836,
#  ('grade', 'generally'): 13.570152184555836,
#  ('eighth', 'speaking'): 13.722155278000887,
#  ('grade', 'speaking'): 13.13719277727973,
#  ('generally', 'speaking'): 10.98518968383468,
#  ('generally', 'expansion'): 10.11072056591854,
#  ('speaking', 'expansion'): 11.262723659363589,
#  ('expansion', 'elementary'): 14.432648660805901,
#  ('elementary', 'book'): 15.570152184555836,
#  ('book', 'addition'): 9.663261588947318,
#  ('addition', 'forty'): 9.712171189428265,
#  ('forty', 'fifty'): 8.946636443065287,
#  ('forty', 'thousand'): 9.57466766567833,
#  ('fifty', 'thousand'): 10.122793398219114,
#  ('fifty', 'words'): 9.804617438192858,
#  ('thousand', 'words'): 9.210256239469453,
#  ('high', 'school'): 11.05357665881493,
#  ('high', 'manual'): 12.20557975225998,
#  ('school', 'manual'): 15.155114685276992,
#  ('This', 'ordinarily'): 8.164159824879999,
#  ('This', 'follows'): 8.579197324158843,
#  ('ordinarily', 'follows'): 15.8920802794432,
#  ('ordinarily', 'beaten'): 12.432648660805901,
#  ('follows', 'beaten'): 13.847686160084745,
#  ('follows', 'path'): 12.722155278000887,
#  ('beaten', 'path'): 12.432648660805901,
#  ('beaten', 'giving'): 10.525758065197383,
#  ('path', 'giving'): 11.722155278000887,
#  ('beaten', 'fuller'): 14.432648660805901,
#  ('path', 'fuller'): 15.307117778722043,
#  ('giving', 'fuller'): 14.570152184555836,
#  ('path', 'accounts'): 12.307117778722043,
#  ('giving', 'accounts'): 11.98518968383468,
#  ('fuller', 'accounts'): 17.477042780164354,
#  ('events', 'characters'): 11.579197324158843,
#  ('To', 'put'): 5.878757606017751,
#  ('To', 'bluntly'): 8.994234823437687,
#  ('put', 'bluntly'): 11.60667806058095,
#  ('assume', 'children'): 8.982187195673157,
#  ('children', 'obtain'): 11.097664413093092,
#  ('children', 'permanent'): 9.097664413093092,
#  ('obtain', 'permanent'): 11.722155278000887,
#  ('children', 'possessions'): 10.097664413093092,
#  ('obtain', 'possessions'): 13.13719277727973,
#  ('permanent', 'possessions'): 12.307117778722043,
#  ('possessions', 'study'): 11.722155278000887,
#  ('study', 'history'): 10.236728450830645,
#  ('history', 'lower'): 6.9762009006074255,
#  ('lower', 'grades'): 14.690446418273549,
#  ('If', 'mathematicians'): 11.663261588947318,
#  ('If', 'followed'): 5.415334075503732,
#  ('mathematicians', 'followed'): 12.644152765999612,
#  ('followed', 'method'): 8.059190265278456,
#  ('method', 'high'): 9.20557975225998,
#  ('method', 'school'): 10.98518968383468,
#  ('method', 'texts'): 13.307117778722043,
#  ('high', 'texts'): 11.20557975225998,
#  ('school', 'texts'): 14.155114685276992,
#  ('school', 'algebra'): 13.570152184555836,
#  ('texts', 'algebra'): 17.8920802794432,
#  ('algebra', 'geometry'): 18.8920802794432,
#  ('algebra', 'would'): 10.150613293042051,
#  ('geometry', 'would'): 11.735575793763207,
#  ('geometry', 'include'): 15.8920802794432,
#  ('would', 'include'): 8.735575793763207,
#  ('would', 'multiplication'): 9.150613293042051,
#  ('include', 'multiplication'): 14.8920802794432,
#  ('include', 'table'): 11.722155278000887,
#  ('multiplication', 'table'): 15.307117778722043,
#  ('multiplication', 'fractions'): 16.8920802794432,
#  ('table', 'fractions'): 15.722155278000887,
#  ('There', 'course'): 6.098883420382254,
#  ('course', 'ready'): 7.136358125800917,
#  ('course', 'answer'): 6.21436063780219,
#  ('ready', 'answer'): 10.059190265278456,
#  ('answer', 'criticism'): 8.262723659363589,
#  ('criticism', 'advanced'): 10.159630166399486,
#  ('It', 'teachers'): 5.965043110722904,
#  ('teachers', 'learned'): 10.909086704748889,
#  ('learned', 'bitter'): 10.461627727777667,
#  ('learned', 'experience'): 9.510537328258614,
#  ('bitter', 'experience'): 11.29713369014942,
#  ('bitter', 'little'): 6.718403143139779,
#  ('experience', 'little'): 7.767312743620725,
#  ('experience', 'history'): 6.641781861536866,
#  ('little', 'history'): 6.817938816690693,
#  ('little', 'pupils'): 10.625293738748297,
#  ('history', 'pupils'): 11.499762856664438,
#  ('history', 'retain'): 9.499762856664438,
#  ('pupils', 'retain'): 16.477042780164354,
#  ('retain', 'pass'): 11.432648660805901,
#  ('pass', 'along'): 10.59134640682496,
#  ('pass', 'regular'): 8.478452350419026,
#  ('along', 'regular'): 8.511619214354226,
#  ('along', 'route'): 8.37835268349076,
#  ('regular', 'route'): 10.43538362852714,
#  ('No', 'teacher'): 10.579197324158843,
#  ('No', 'history'): 5.771842402101239,
#  ('teacher', 'history'): 10.914800355943282,
#  ('history', 'deny'): 9.914800355943282,
#  ('standing', 'challenge'): 11.58222501685641,
#  ('standing', 'existing'): 10.384285639244503,
#  ('challenge', 'existing'): 11.104177720051768,
#  ('challenge', 'methods'): 8.71715459694252,
#  ('existing', 'methods'): 10.689140220772924,
#  ('existing', 'historical'): 10.869712466414745,
#  ('methods', 'historical'): 10.482689343305497,
#  ('methods', 'instruction'): 10.219654937471702,
#  ('historical', 'instruction'): 13.570152184555836,
#  ('If', 'study'): 8.078299088226162,
#  ('made', 'truly'): 9.219654937471702,
#  ('made', 'progressive'): 7.17526081811325,
#  ('truly', 'progressive'): 14.017611161527057,
#  ('made', 'like'): 3.0347795945634193,
#  ('truly', 'like'): 10.29216743725607,
#  ('progressive', 'like'): 9.41769831933993,
#  ('progressive', 'study'): 10.847686160084745,
#  ('like', 'study'): 8.707204936534914,
#  ('study', 'mathematics'): 15.307117778722043,
#  ('study', 'science'): 10.722155278000887,
#  ('mathematics', 'science'): 15.8920802794432,
#  ('mathematics', 'languages'): 15.570152184555836,
#  ('science', 'languages'): 12.98518968383468,
#  ('languages', 'historians'): 12.762797262498232,
#  ('historians', 'assume'): 12.969248139965659,
#  ('historians', 'grave'): 11.27737043532799,
#  ('assume', 'grave'): 11.384285639244503,
#  ('assume', 'responsibility'): 10.491200843161014,
#  ('grave', 'responsibility'): 11.969248139965659,
#  ('grave', 'adding'): 10.914800355943282,
#  ('responsibility', 'adding'): 12.021715559859794,
#  ('adding', 'subject'): 9.864174282873314,
#  ('subject', 'already'): 6.542246187985952,
#  ('already', 'overloaded'): 13.98518968383468,
#  ('already', 'curriculum'): 13.400227183113524,
#  ('overloaded', 'curriculum'): 19.477042780164354,
#  ('If', 'successive'): 9.663261588947318,
#  ('If', 'historical'): 8.341333494059954,
#  ('successive', 'historical'): 14.155114685276992,
#  ('successive', 'texts'): 15.8920802794432,
#  ('historical', 'texts'): 15.155114685276992,
#  ('texts', 'enlarged'): 12.98518968383468,
#  ('enlarged', 'editions'): 12.762797262498232,
#  ('editions', 'first'): 7.067917069699041,
#  ('first', 'text'): 8.415840373119348,
#  ('first', 'facts'): 6.415840373119347,
#  ('text', 'facts'): 11.973217042168605,
#  ('facts', 'dates'): 15.432648660805901,
#  ('dates', 'words'): 14.8920802794432,
#  ('words', 'history'): 8.499762856664438,
#  ('words', 'deserves'): 12.8920802794432,
#  ('history', 'deserves'): 12.084725357385594,
#  ('sharp', 'criticism'): 12.210256239469453,
#  ('receiving', 'teachers'): 12.625293738748297,
#  ('teachers', 'science'): 11.847686160084745,
#  ('teachers', 'civics'): 14.432648660805901,
#  ('science', 'civics'): 15.8920802794432,
#  ('science', 'economics'): 13.307117778722043,
#  ('civics', 'economics'): 17.8920802794432,
#  ('In', 'condition'): 3.297230857688833,
#  ('condition', 'affairs'): 8.59287226105592,
#  ('affairs', 'find'): 7.552230276558574,
#  ('find', 'justification'): 12.13719277727973,
#  ('justification', 'offering'): 14.499762856664438,
#  ('offering', 'new'): 8.034876807935033,
#  ('offering', 'high'): 8.398224830202377,
#  ('new', 'high'): 4.7406937035305745,
#  ('new', 'school'): 7.520303635105274,
#  ('new', 'text'): 6.38280011135534,
#  ('high', 'text'): 8.746148133622683,
#  ('school', 'text'): 11.695683066639695,
#  ('school', 'American'): 4.052482796422025,
#  ('text', 'American'): 5.914979272672089,
#  ('text', 'history'): 8.040331238027141,
#  ('Our', 'first'): 5.482954568977885,
#  ('Our', 'contribution'): 12.499762856664438,
#  ('first', 'contribution'): 9.875271991756644,
#  ('first', 'one'): 3.50023256040972,
#  ('contribution', 'one'): 9.195112753208912,
#  ('one', 'omission'): 10.195112753208912,
#  ('The', 'time'): 1.4602562514353359,
#  ('The', 'honored'): 5.186879901380083,
#  ('The', 'stories'): 3.6019174006589267,
#  ('time', 'honored'): 10.995531628056138,
#  ('time', 'stories'): 7.603214205277379,
#  ('honored', 'stories'): 14.722155278000887,
#  ('honored', 'exploration'): 13.722155278000887,
#  ('stories', 'exploration'): 13.13719277727973,
#  ('exploration', 'biographies'): 14.307117778722043,
#  ('biographies', 'heroes'): 15.307117778722043,
#  ('heroes', 'left'): 10.60667806058095,
#  ('We', 'frankly'): 10.352921468335168,
#  ('We', 'hold'): 6.89348984969787,
#  ('frankly', 'hold'): 12.262723659363589,
#  ('hold', 'pupils'): 11.847686160084745,
#  ('pupils', 'know'): 14.570152184555836,
#  ('pupils', 'little'): 11.625293738748297,
#  ('know', 'little'): 10.303365643860936,
#  ('know', 'nothing'): 8.430600832157042,
#  ('little', 'nothing'): 7.07070488707066,
#  ('nothing', 'Columbus'): 11.752528927044406,
#  ('nothing', 'Cortes'): 11.337491427765562,
#  ('Columbus', 'Cortes'): 16.8920802794432,
#  ('Columbus', 'Magellan'): 16.30711777872204,
#  ('Cortes', 'Magellan'): 17.477042780164354,
#  ('Cortes', 'Captain'): 14.307117778722043,
#  ('Magellan', 'Captain'): 15.307117778722043,
#  ('Magellan', 'John'): 10.150613293042051,
#  ('Captain', 'John'): 11.735575793763207,
#  ('Captain', 'Smith'): 14.13719277727973,
#  ('John', 'Smith'): 11.150613293042051,
#  ('Smith', 'time'): 6.603214205277379,
#  ('time', 'reach'): 7.313707588082394,
#  ('reach', 'high'): 8.746148133622683,
#  ('reach', 'school'): 10.11072056591854,
#  ('school', 'useless'): 10.98518968383468,
#  ('useless', 'tell'): 13.13719277727973,
#  ('tell', 'stories'): 11.552230276558573,
#  ('stories', 'perhaps'): 12.021715559859794,
#  ('perhaps', 'fourth'): 10.869712466414745,
#  ('perhaps', 'time'): 6.072699488578599,
#  ('fourth', 'time'): 7.036173612553485,
#  ('It', 'worse'): 6.424474729360201,
#  ('worse', 'useless'): 13.307117778722043,
#  ('It', 'offense'): 6.424474729360201,
#  ('offense', 'teachers'): 11.432648660805901,
#  ('teachers', 'subjects'): 9.909086704748889,
#  ('subjects', 'demonstrated'): 11.368518323386185,
#  ('demonstrated', 'progressive'): 12.432648660805901,
#  ('progressive', 'character'): 9.973217042168605,
#  ('In', 'next'): 3.1785863611902143,
#  ('In', 'place'): 6.794245659134287,
#  ('next', 'place'): 7.689956455612738,
#  ('place', 'omitted'): 11.352921468335168,
#  ('omitted', 'descriptions'): 17.30711777872204,
#  ('descriptions', 'battles'): 13.98518968383468,
#  ('Our', 'reasons'): 9.329837855222125,
#  ('The', 'strategy'): 3.7718424021012393,
#  ('strategy', 'campaign'): 8.825991088985425,
#  ('single', 'battle'): 8.312764341863184,
#  ('battle', 'highly'): 8.341333494059954,
#  ('highly', 'technical'): 13.347759763219388,
#  ('highly', 'usually'): 10.177834761777076,
#  ('technical', 'usually'): 11.692407934606834,
#  ('usually', 'highly'): 11.177834761777076,
#  ('usually', 'controversial'): 13.499762856664438,
#  ('highly', 'controversial'): 16.155114685276992,
#  ('highly', 'matter'): 9.815264682392367,
#  ('controversial', 'matter'): 13.722155278000887,
#  ('matter', 'experts'): 12.13719277727973,
#  ('experts', 'differ'): 18.477042780164354,
#  ('experts', 'widely'): 14.248224089668474,
#  ('differ', 'widely'): 13.83318659038963,
#  ('In', 'field'): 5.742015700361729,
#  ('field', 'military'): 6.785517338998315,
#  ('military', 'naval'): 10.692407934606834,
#  ('military', 'operations'): 9.561163401328582,
#  ('naval', 'operations'): 10.046590228498824,
#  ('naval', 'writers'): 9.525758065197383,
#  ('operations', 'writers'): 10.909086704748889,
#  ('writers', 'teachers'): 11.973217042168605,
#  ('teachers', 'history'): 9.040331238027141,
#  ('history', 'mere'): 7.744875354500969,
#  ('history', 'novices'): 10.499762856664438,
#  ('mere', 'novices'): 13.722155278000887,
#  ('To', 'dispose'): 7.771842402101239,
#  ('To', 'Gettysburg'): 7.994234823437687,
#  ('dispose', 'Gettysburg'): 13.499762856664438,
#  ('Gettysburg', 'Wilderness'): 15.307117778722043,
#  ('Wilderness', 'ten'): 13.034099284315626,
#  ('Wilderness', 'lines'): 12.682626913814248,
#  ('ten', 'lines'): 8.409608419407833,
#  ('ten', 'ten'): 6.176118289188055,
#  ('lines', 'ten'): 7.824645918686676,
#  ('lines', 'pages'): 10.097664413093092,
#  ('ten', 'pages'): 11.034099284315626,
#  ('ten', 'equally'): 6.786171770872041,
#  ('pages', 'equally'): 11.059190265278456,
#  ('pages', 'absurd'): 12.98518968383468,
#  ('equally', 'absurd'): 11.907187171833407,
#  ('absurd', 'serious'): 11.11072056591854,
#  ('serious', 'student'): 13.432648660805901,
#  ('serious', 'military'): 6.817938816690693,
#  ('student', 'military'): 10.692407934606834,
#  ('student', 'affairs'): 10.13719277727973,
#  ('military', 'affairs'): 8.692407934606834,
#  ('Any', 'one'): 7.195112753208912,
#  ('Any', 'compares'): 14.8920802794432,
#  ('one', 'compares'): 10.195112753208912,
#  ('compares', 'ordinary'): 14.804617438192858,
#  ('compares', 'textbook'): 16.8920802794432,
#  ('ordinary', 'textbook'): 14.389579938914016,
#  ('ordinary', 'account'): 9.37835268349076,
#  ('textbook', 'account'): 13.050778025462257,
#  ('account', 'single'): 6.793390182769605,
#  ('single', 'Civil'): 7.328884007226462,
#  ('single', 'War'): 5.380451149374759,
#  ('Civil', 'War'): 11.390924251596894,
#  ('single', 'campaign'): 6.15356574701393,
#  ('Civil', 'campaign'): 6.350257658019029,
#  ('War', 'campaign'): 5.571749801609638,
#  ('campaign', 'account'): 6.399726334283328,
#  ('account', 'given'): 8.07349810196234,
#  ('account', 'Ropes'): 11.465815524741101,
#  ('given', 'Ropes'): 11.499762856664438,
#  ('Ropes', 'instance'): 14.191640561302107,
#  ('instance', 'ask'): 12.191640561302107,
#  ('No', 'youth'): 9.356804902822395,
#  ('No', 'called'): 6.609570973202362,
#  ('No', 'upon'): 3.5384509818155343,
#  ('youth', 'called'): 9.530136505707958,
#  ('youth', 'upon'): 7.459016514321129,
#  ('called', 'upon'): 8.439703039264295,
#  ('called', 'serve'): 8.015563332878198,
#  ('upon', 'serve'): 6.944443341491371,
#  ('serve', 'country'): 7.509456252868282,
#  ('country', 'arms'): 5.33953125142597,
#  ('country', 'would'): 3.0899173613544977,
#  ('arms', 'would'): 6.243722697433533,
#  ('arms', 'think'): 8.940795564476227,
#  ('would', 'think'): 8.013109769292116,
#  ('would', 'turning'): 6.980688291599739,
#  ('think', 'turning'): 11.262723659363589,
#  ('turning', 'high'): 8.035654750817669,
#  ('school', 'information'): 10.570152184555836,
#  ('manual', 'information'): 14.8920802794432,
#  ('information', 'art'): 11.570152184555836,
#  ('art', 'warfare'): 12.482689343305497,
#  ('The', 'dramatic'): 4.771842402101239,
#  ('The', 'scene'): 3.6019174006589267,
#  ('dramatic', 'scene'): 12.722155278000887,
#  ('dramatic', 'episode'): 15.8920802794432,
#  ('scene', 'episode'): 14.722155278000887,
#  ('episode', 'useful'): 16.8920802794432,
#  ('useful', 'arousing'): 15.8920802794432,
#  ('arousing', 'interest'): 12.191640561302107,
#  ('interest', 'immature'): 11.191640561302107,
#  ('immature', 'pupil'): 19.477042780164354,
#  ('immature', 'seems'): 15.084725357385594,
#  ('pupil', 'seems'): 15.66968785810675,
#  ('seems', 'place'): 7.545566546277563,
#  ('place', 'book'): 7.446030872726649,
#  ('book', 'deliberately'): 12.177834761777076,
#  ('book', 'appeals'): 10.98518968383468,
#  ('deliberately', 'appeals'): 13.66968785810675,
#  ('deliberately', 'boys'): 12.27737043532799,
#  ('appeals', 'boys'): 13.084725357385594,
#  ('boys', 'girls'): 14.821690951551801,
#  ('threshold', 'life'): 11.150613293042051,
#  ('life', 'serious'): 7.6911816744047545,
#  ('life', 'responsibilities'): 9.150613293042051,
#  ('serious', 'responsibilities'): 13.017611161527057,
#  ('It', 'upon'): 3.60612080835334,
#  ('upon', 'negative'): 8.85133393709989,
#  ('upon', 'features'): 6.806939817741436,
#  ('negative', 'features'): 13.017611161527057,
#  ('upon', 'however'): 4.096446434936421,
#  ('negative', 'however'): 10.13719277727973,
#  ('features', 'however'): 8.262723659363589,
#  ('however', 'rest'): 5.92773941165078,
#  ('rest', 'case'): 8.512701912371936,
#  ('It', 'rather'): 3.9326216330305264,
#  ('rather', 'upon'): 5.359480840770215,
#  ('rather', 'constructive'): 11.078299088226162,
#  ('upon', 'constructive'): 8.529405842212528,
#  ('rather', 'features'): 7.940795564476226,
#  ('constructive', 'features'): 12.695683066639695,
#  ('First', 'We'): 7.689956455612738,
#  ('First', 'written'): 9.059190265278456,
#  ('We', 'written'): 8.352921468335168,
#  ('written', 'topical'): 11.98518968383468,
#  ('topical', 'narrative'): 12.98518968383468,
#  ('narrative', 'history'): 10.499762856664438,
#  ('We', 'tried'): 7.850421127805984,
#  ('tried', 'set'): 8.17526081811325,
#  ('tried', 'forth'): 8.04972993602939,
#  ('set', 'forth'): 11.340726171364862,
#  ('set', 'important'): 5.481363945838929,
#  ('forth', 'important'): 7.35583306375507,
#  ('forth', 'aspects'): 9.329837855222125,
#  ('important', 'aspects'): 10.888328144582092,
#  ('important', 'problems'): 7.525758065197383,
#  ('aspects', 'problems'): 11.084725357385594,
#  ('aspects', 'movements'): 12.499762856664438,
#  ('problems', 'movements'): 10.722155278000887,
#  ('movements', 'period'): 9.525758065197383,
#  ('period', 'bringing'): 10.236251448002399,
#  ('bringing', 'narrative'): 11.847686160084745,
#  ('narrative', 'rather'): 11.400227183113524,
#  ('narrative', 'way'): 8.068713039396963,
#  ('rather', 'way'): 6.161822443788445,
#  ('way', 'illustration'): 9.653675540118119,
#  ('Second', 'We'): 9.352921468335168,
#  ('Second', 'emphasized'): 12.98518968383468,
#  ('We', 'emphasized'): 10.61595587416896,
#  ('emphasized', 'historical'): 13.248224089668474,
#  ('emphasized', 'topics'): 13.98518968383468,
#  ('historical', 'topics'): 14.570152184555836,
#  ('historical', 'help'): 9.762797262498232,
#  ('topics', 'help'): 12.499762856664438,
#  ('help', 'explain'): 11.27737043532799,
#  ('explain', 'nation'): 8.545566546277563,
#  ('nation', 'come'): 6.3987251579482916,
#  ('Third', 'We'): 10.937883969056323,
#  ('Third', 'dwelt'): 14.570152184555836,
#  ('We', 'dwelt'): 10.61595587416896,
#  ('We', 'fully'): 8.61595587416896,
#  ('dwelt', 'fully'): 13.83318659038963,
#  ('dwelt', 'upon'): 9.266371436378734,
#  ('fully', 'upon'): 7.529405842212527,
#  ('fully', 'social'): 9.400227183113524,
#  ('upon', 'social'): 6.418374529823783,
#  ('social', 'economic'): 7.512701912371936,
#  ('social', 'aspects'): 9.914800355943282,
#  ('economic', 'aspects'): 12.045196993198957,
#  ('aspects', 'history'): 8.692407934606834,
#  ('history', 'especially'): 7.727173352767511,
#  ('history', 'relation'): 6.799323138523346,
#  ('especially', 'relation'): 9.834088556684023,
#  ('relation', 'politics'): 7.0831161045239375,
#  ('politics', 'period'): 7.587158609861526,
#  ('Fourth', 'We'): 10.937883969056323,
#  ('Fourth', 'treated'): 12.8920802794432,
#  ('We', 'treated'): 8.937883969056323,
#  ('treated', 'causes'): 11.570152184555836,
#  ('causes', 'results'): 10.177834761777076,
#  ('results', 'wars'): 9.177834761777076,
#  ('wars', 'problems'): 8.400227183113524,
#  ('problems', 'financing'): 10.98518968383468,
#  ('financing', 'sustaining'): 14.248224089668474,
#  ('financing', 'armed'): 10.663261588947318,
#  ('sustaining', 'armed'): 12.248224089668474,
#  ('sustaining', 'forces'): 10.230302181671211,
#  ('armed', 'forces'): 10.815264682392367,
#  ('sustaining', 'rather'): 10.078299088226162,
#  ('armed', 'rather'): 8.493336587505006,
#  ('forces', 'rather'): 7.645339680950055,
#  ('forces', 'military'): 5.937520432443366,
#  ('rather', 'military'): 6.785517338998315,
#  ('rather', 'strategy'): 9.400227183113524,
#  ('military', 'strategy'): 11.447295436770302,
#  ('These', 'subjects'): 7.724662133611461,
#  ('subjects', 'belong'): 12.368518323386185,
#  ('belong', 'history'): 9.499762856664438,
#  ('history', 'civilians'): 9.692407934606834,
#  ('These', 'matters'): 6.926295994781111,
#  ('matters', 'civilians'): 10.762797262498232,
#  ('civilians', 'understand'): 13.084725357385594,
#  ('civilians', 'matters'): 9.762797262498232,
#  ('understand', 'matters'): 11.155114685276992,
#  ('matters', 'must'): 5.883651657372618,
#  ('must', 'understand'): 9.790542252981137,
#  ('play', 'well'): 8.596693972008328,
#  ('play', 'part'): 8.538198322698184,
#  ('well', 'part'): 5.473766450103185,
#  ('part', 'war'): 3.3272460529958163,
#  ('war', 'peace'): 5.364016931151245,
#  ('Fifth', 'By'): 11.071901317028011,
#  ('Fifth', 'omitting'): 16.8920802794432,
#  ('By', 'omitting'): 11.071901317028011,
#  ('By', 'period'): 5.2905416035033515,
#  ('omitting', 'period'): 12.11072056591854,
#  ('period', 'exploration'): 10.525758065197383,
#  ('able', 'enlarge'): 10.72717335276751,
#  ('enlarge', 'treatment'): 13.084725357385594,
#  ('We', 'given'): 5.545566546277563,
#  ('We', 'special'): 6.9836876586694485,
#  ('given', 'special'): 8.130529046998719,
#  ('given', 'attention'): 8.107445433885678,
#  ('special', 'attention'): 10.130529046998719,
#  ('attention', 'history'): 7.107445433885678,
#  ('history', 'current'): 7.177834761777076,
#  ('current', 'questions'): 9.728849930574894,
#  ('current', 'must'): 6.883651657372618,
#  ('questions', 'must'): 6.779314997557882,
#  ('questions', 'form'): 6.199028984046199,
#  ('must', 'form'): 6.523755712286235,
#  ('must', 'subject'): 5.347598757132408,
#  ('form', 'subject'): 6.767312743620725,
#  ('form', 'matter'): 5.870406236584829,
#  ('subject', 'matter'): 7.864174282873314,
#  ('subject', 'sound'): 8.333659566174534,
#  ('matter', 'sound'): 9.436753059138638,
#  ('matter', 'instruction'): 9.552230276558573,
#  ('sound', 'instruction'): 13.191640561302107,
#  ('sound', 'citizenship'): 10.869712466414745,
#  ('instruction', 'citizenship'): 12.98518968383468,
#  ('Sixth', 'We'): 11.937883969056323,
#  ('Sixth', 'borne'): 15.8920802794432,
#  ('We', 'borne'): 10.937883969056323,
#  ('borne', 'mind'): 12.034099284315626,
#  ('mind', 'America'): 5.941342143395774,
#  ('unique', 'characteristics'): 15.155114685276992,
#  ('characteristics', 'part'): 8.653675540118119,
#  ('part', 'general'): 4.483750538675808,
#  ('general', 'civilization'): 8.400227183113524,
#  ('Accordingly', 'given'): 8.177834761777076,
#  ('given', 'diplomacy'): 8.561163401328582,
#  ('given', 'foreign'): 5.9762009006074255,
#  ('diplomacy', 'foreign'): 8.42991886805033,
#  ('given', 'affairs'): 5.3298378552221255,
#  ('diplomacy', 'affairs'): 8.198593321943873,
#  ('foreign', 'affairs'): 8.368518323386185,
#  ('diplomacy', 'world'): 6.844956367329173,
#  ('foreign', 'world'): 7.166884462216536,
#  ('affairs', 'world'): 6.783555822665029,
#  ('foreign', 'relations'): 7.942253568684087,
#  ('affairs', 'relations'): 7.295890523298788,
#  ('world', 'relations'): 7.527216069405244,
#  ('relations', 'reciprocal'): 11.465815524741101,
#  ('reciprocal', 'influences'): 17.477042780164354,
#  ('reciprocal', 'nations'): 11.27737043532799,
#  ('influences', 'nations'): 12.27737043532799,
#  ('nations', 'appropriate'): 9.5769307171869,
#  ('nations', 'place'): 5.738211624219959,
#  ('appropriate', 'place'): 9.237444250915232,
#  ('Seventh', 'We'): 10.937883969056323,
#  ('Seventh', 'deliberately'): 14.084725357385594,
#  ('We', 'deliberately'): 10.130529046998719,
#  ('We', 'aimed'): 10.130529046998719,
#  ('deliberately', 'aimed'): 14.862332936049146,
#  ('deliberately', 'standards'): 12.27737043532799,
#  ('aimed', 'standards'): 13.27737043532799,
#  ('standards', 'maturity'): 14.499762856664438,
#  ('The', 'study'): 3.186879901380083,
#  ('study', 'mere'): 9.552230276558573,
#  ('mere', 'narrative'): 12.13719277727973,
#  ('mere', 'calls'): 12.552230276558573,
#  ('narrative', 'calls'): 15.307117778722043,
#  ('mere', 'mainly'): 7.464767435308234,
#  ('narrative', 'mainly'): 10.634692436750546,
#  ('calls', 'mainly'): 12.219654937471702,
#  ('mainly', 'use'): 5.862102932853619,
#  ('use', 'memory'): 9.94956577410396,
#  ('aimed', 'stimulate'): 14.499762856664438,
#  ('aimed', 'habits'): 11.499762856664438,
#  ('stimulate', 'habits'): 14.307117778722043,
#  ('stimulate', 'analysis'): 14.307117778722043,
#  ('habits', 'analysis'): 13.307117778722043,
#  ('habits', 'comparison'): 11.499762856664438,
#  ('analysis', 'comparison'): 14.66968785810675,
#  ('analysis', 'association'): 12.804617438192858,
#  ('comparison', 'association'): 12.58222501685641,
#  ('analysis', 'reflection'): 15.8920802794432,
#  ('comparison', 'reflection'): 16.084725357385594,
#  ('association', 'reflection'): 15.389579938914016,
#  ('association', 'generalization'): 13.804617438192858,
#  ('reflection', 'generalization'): 18.8920802794432,
#  ('reflection', 'habits'): 14.307117778722043,
#  ('generalization', 'habits'): 15.8920802794432,
#  ('generalization', 'calculated'): 15.722155278000887,
#  ('habits', 'calculated'): 12.722155278000887,
#  ('habits', 'enlarge'): 11.499762856664438,
#  ('calculated', 'enlarge'): 12.914800355943282,
#  ('enlarge', 'well'): 8.90481626737066,
#  ('well', 'inform'): 10.712171189428265,
#  ('inform', 'mind'): 13.034099284315626,
#  ('great', 'pains'): 10.059190265278456,
#  ('great', 'make'): 4.116675759939217,
#  ('pains', 'make'): 10.364603273382803,
#  ('make', 'text'): 8.490134155466661,
#  ('make', 'clear'): 5.905171654745505,
#  ('text', 'clear'): 10.973217042168605,
#  ('text', 'simple'): 10.432648660805901,
#  ('clear', 'simple'): 10.169614254972107,
#  ('clear', 'direct'): 7.092798657921277,
#  ('simple', 'direct'): 8.13719277727973,
#  ('earnestly', 'sought'): 13.862332936049146,
#  ('earnestly', 'stretch'): 16.8920802794432,
#  ('sought', 'stretch'): 13.27737043532799,
#  ('stretch', 'intellects'): 17.8920802794432,
#  ('intellects', 'readers'): 15.307117778722043,
#  ('readers', 'put'): 11.021715559859794,
#  ('put', 'upon'): 6.150894218958797,
#  ('upon', 'mettle'): 10.266371436378734,
#  ('receive', 'last'): 8.329837855222125,
#  ('last', 'formal'): 7.914800355943282,
#  ('formal', 'instruction'): 13.307117778722043,
#  ('instruction', 'high'): 8.620617251538825,
#  ('The', 'world'): 1.8332429467653824,
#  ('The', 'soon'): 0.3795249793224788,
#  ('world', 'soon'): 5.9762009006074255,
#  ('world', 'expect'): 9.368518323386185,
#  ('soon', 'expect'): 11.084725357385594,
#  ('soon', 'maturity'): 10.914800355943282,
#  ('expect', 'maturity'): 15.8920802794432,
#  ('Their', 'achievements'): 9.436753059138638,
#  ('Their', 'depend'): 11.60667806058095,
#  ('achievements', 'depend'): 14.722155278000887,
#  ('achievements', 'upon'): 6.096446434936421,
#  ('depend', 'upon'): 10.85133393709989,
#  ('depend', 'possession'): 12.084725357385594,
#  ('upon', 'possession'): 5.459016514321129,
#  ('possession', 'powers'): 6.370479839719471,
#  ('powers', 'memory'): 10.59287226105592,
#  ('powers', 'alone'): 5.654272805720063,
#  ('memory', 'alone'): 12.368518323386185,
#  ('The', 'effectiveness'): 6.771842402101239,
#  ('effectiveness', 'citizenship'): 14.570152184555836,
#  ('citizenship', 'republic'): 9.248224089668474,
#  ('republic', 'measured'): 9.400227183113524,
#  ('measured', 'excellence'): 13.722155278000887,
#  ('excellence', 'judgment'): 12.8920802794432,
#  ('judgment', 'well'): 7.712171189428264,
#  ('well', 'fullness'): 9.127208688707109,
#  ('fullness', 'information'): 13.307117778722043,
#  ('C', 'A'): 5.91682937929284,
#  ('C', 'B'): 7.250028586515222,
#  ('A', 'B'): 9.046920402442566,
#  ('M', 'R'): 8.388254541447449,
#  ('M', 'B'): 8.345185819555562,
#  ('R', 'B'): 8.760223318834406,
#  ('NEW', 'YORK'): 15.055579011726078,
#  ('NEW', 'CITY'): 14.377507106613441,
#  ('NEW', 'February'): 8.570152184555836,
#  ('YORK', 'CITY'): 17.029583803193134,
#  ('YORK', 'February'): 11.570152184555836,
#  ('CITY', 'February'): 12.477042780164355,
#  ('YORK', '8'): 9.89772684258434,
#  ('CITY', '8'): 11.219654937471702,
#  ('February', '8'): 9.804617438192858,
#  ('CITY', '1921'): 13.8920802794432,
#  ('February', '1921'): 11.8920802794432,
#  ('8', '1921'): 11.804617438192858,
#  ('A', 'SMALL'): 9.88645573024932,
#  ('A', 'LIBRARY'): 9.88645573024932,
#  ('A', 'IN'): 7.186016012108229,
#  ('SMALL', 'LIBRARY'): 18.8920802794432,
#  ('SMALL', 'IN'): 13.60667806058095,
#  ('LIBRARY', 'IN'): 14.191640561302107,
#  ('SMALL', 'AMERICAN'): 14.570152184555836,
#  ('LIBRARY', 'AMERICAN'): 15.570152184555836,
#  ('IN', 'AMERICAN'): 10.869712466414745,
#  ('LIBRARY', 'HISTORY'): 15.8920802794432,
#  ('IN', 'HISTORY'): 11.60667806058095,
#  ('AMERICAN', 'HISTORY'): 15.155114685276992,
#  ('IN', 'SINGLE'): 12.60667806058095,
#  ('AMERICAN', 'SINGLE'): 15.570152184555836,
#  ('HISTORY', 'SINGLE'): 17.477042780164354,
#  ('AMERICAN', 'VOLUMES'): 14.570152184555836,
#  ('HISTORY', 'VOLUMES'): 16.8920802794432,
#  ('SINGLE', 'VOLUMES'): 19.477042780164354,
#  ('HISTORY', 'BASSETT'): 15.8920802794432,
#  ('SINGLE', 'BASSETT'): 18.8920802794432,
#  ('VOLUMES', 'BASSETT'): 19.477042780164354,
#  ('SINGLE', 'J'): 11.762797262498232,
#  ('VOLUMES', 'J'): 12.762797262498232,
#  ('BASSETT', 'J'): 13.347759763219388,
#  ('VOLUMES', 'S'): 12.722155278000887,
#  ('BASSETT', 'S'): 13.722155278000887,
#  ('J', 'S'): 9.762797262498232,
#  ('A', 'Short'): 5.564527635361959,
#  ('A', 'History'): 5.648050990924242,
#  ('Short', 'History'): 12.086634947394225,
#  ('History', 'United'): 7.5585183070777795,
#  ('United', 'States'): 10.418551048128135,
#  ('United', 'ELSON'): 10.015563332878198,
#  ('States', 'ELSON'): 10.438123790872053,
#  ('United', 'H'): 3.208208410820595,
#  ('States', 'H'): 4.045806368093292,
#  ('ELSON', 'H'): 13.66968785810675,
#  ('States', 'W'): 3.0982737879874276,
#  ('ELSON', 'W'): 13.13719277727973,
#  ('H', 'W'): 9.499762856664438,
#  ('United', 'America'): 3.9228061919583466,
#  ('States', 'America'): 4.930329150673356,
#  ('States', 'SERIES'): 7.853161290150896,
#  ('America', 'SERIES'): 10.384285639244503,
#  ('America', 'EPOCHS'): 10.799323138523347,
#  ('SERIES', 'EPOCHS'): 18.477042780164354,
#  ('America', 'OF'): 3.057856152122199,
#  ('SERIES', 'OF'): 11.150613293042051,
#  ('EPOCHS', 'OF'): 12.735575793763207,
#  ('SERIES', 'AMERICAN'): 13.570152184555836,
#  ('EPOCHS', 'AMERICAN'): 15.570152184555836,
#  ('OF', 'AMERICAN'): 10.998610199597001,
#  ('EPOCHS', 'HISTORY'): 15.8920802794432,
#  ('OF', 'HISTORY'): 10.735575793763207,
#  ('OF', 'EDITED'): 10.150613293042051,
#  ('AMERICAN', 'EDITED'): 14.570152184555836,
#  ('HISTORY', 'EDITED'): 16.477042780164354,
#  ('AMERICAN', 'BY'): 12.570152184555836,
#  ('HISTORY', 'BY'): 14.8920802794432,
#  ('EDITED', 'BY'): 17.477042780164354,
#  ('HISTORY', 'A'): 7.88645573024932,
#  ('EDITED', 'A'): 9.88645573024932,
#  ('BY', 'A'): 9.471418230970476,
#  ('EDITED', 'B'): 11.804617438192858,
#  ('BY', 'B'): 11.804617438192858,
#  ('HART', 'HART'): 15.8920802794432,
#  ('HART', 'A'): 10.471418230970476,
#  ('HART', 'B'): 13.389579938914016,
#  ('Formation', 'Union'): 10.11072056591854,
#  ('Union', 'THWAITES'): 14.017611161527057,
#  ('Union', 'R'): 8.388254541447449,
#  ('THWAITES', 'R'): 14.432648660805901,
#  ('Union', 'G'): 7.525758065197383,
#  ('THWAITES', 'G'): 13.98518968383468,
#  ('R', 'G'): 10.525758065197383,
#  ('The', 'Colonies'): 5.549449980764791,
#  ('The', 'WILSON'): 4.771842402101239,
#  ('The', 'WOODROW'): 6.771842402101239,
#  ('Colonies', 'WILSON'): 13.084725357385594,
#  ('Colonies', 'WOODROW'): 15.084725357385594,
#  ('WILSON', 'WOODROW'): 17.477042780164354,
#  ('Division', 'Reunion'): 17.8920802794432,
#  ('Division', 'RIVERSIDE'): 17.8920802794432,
#  ('Reunion', 'RIVERSIDE'): 19.477042780164354,
#  ('Reunion', 'SERIES'): 17.8920802794432,
#  ('RIVERSIDE', 'SERIES'): 18.477042780164354,
#  ('Reunion', 'EDITED'): 16.8920802794432,
#  ('RIVERSIDE', 'EDITED'): 17.8920802794432,
#  ('SERIES', 'EDITED'): 17.477042780164354,
#  ('RIVERSIDE', 'BY'): 15.8920802794432,
#  ('SERIES', 'BY'): 15.8920802794432,
#  ('SERIES', 'W'): 11.13719277727973,
#  ('EDITED', 'W'): 12.13719277727973,
#  ('BY', 'W'): 11.722155278000887,
#  ('EDITED', 'E'): 10.762797262498232,
#  ('BY', 'E'): 10.762797262498232,
#  ('W', 'E'): 10.095372601585103,
#  ('DODD', 'BECKER'): 16.8920802794432,
#  ('DODD', 'C'): 11.337491427765562,
#  ('DODD', 'L'): 12.8920802794432,
#  ('BECKER', 'C'): 13.337491427765562,
#  ('BECKER', 'L'): 14.8920802794432,
#  ('C', 'L'): 10.337491427765562,
#  ('Beginnings', 'American'): 5.567055969251783,
#  ('American', 'People'): 8.066288595947055,
#  ('American', 'DODD'): 8.374410891309386,
#  ('People', 'DODD'): 13.776603062023263,
#  ('American', 'W'): 2.619523389145918,
#  ('People', 'W'): 8.436753059138638,
#  ('DODD', 'W'): 12.722155278000887,
#  ('People', 'E'): 7.06235754435714,
#  ('DODD', 'E'): 11.762797262498232,
#  ('Expansion', 'Conflict'): 13.307117778722043,
#  ('Expansion', 'JOHNSON'): 15.307117778722043,
#  ('Conflict', 'JOHNSON'): 17.477042780164354,
#  ('Conflict', 'A'): 8.88645573024932,
#  ('JOHNSON', 'A'): 11.471418230970476,
#  ('Union', 'Democracy'): 7.625293738748297,
#  ('Union', 'PAXSON'): 12.432648660805901,
#  ('Democracy', 'PAXSON'): 14.66968785810675,
#  ('Democracy', 'F'): 9.226744362258023,
#  ('PAXSON', 'F'): 14.619061785036783,
#  ('Democracy', 'L'): 9.084725357385594,
#  ('PAXSON', 'L'): 14.8920802794432,
#  ('F', 'L'): 10.619061785036783,
#  ('The', 'New'): 3.9839398427098076,
#  ('The', 'Nation'): 5.736218492370518,
#  ('The', 'CONTENTS'): 6.771842402101239,
#  ('New', 'Nation'): 8.501513217597152,
#  ('New', 'CONTENTS'): 10.104177720051768,
#  ('Nation', 'CONTENTS'): 14.119490775546272,
#  ('New', 'PART'): 5.296822797994163,
#  ('Nation', 'PART'): 9.72717335276751,
#  ('CONTENTS', 'PART'): 15.66968785810675,
#  ('Nation', 'I'): 5.834088556684023,
#  ('CONTENTS', 'I'): 12.191640561302107,
#  ('PART', 'I'): 9.969248139965659,
#  ('THE', 'COLONIAL'): 9.75625441663146,
#  ('THE', 'PERIOD'): 10.689140220772924,
#  ('THE', 'CHAPTER'): 7.045284030998198,
#  ('COLONIAL', 'PERIOD'): 14.8920802794432,
#  ('COLONIAL', 'CHAPTER'): 11.44086916761087,
#  ('PERIOD', 'CHAPTER'): 13.83318659038963,
#  ('COLONIAL', 'PAGE'): 12.499762856664438,
#  ('PERIOD', 'PAGE'): 15.307117778722043,
#  ('CHAPTER', 'PAGE'): 13.248224089668474,
#  ('PERIOD', 'I'): 10.776603062023263,
#  ('CHAPTER', 'I'): 8.869712466414745,
#  ('PAGE', 'I'): 11.191640561302107,
#  ('THE', 'GREAT'): 11.563609338689064,
#  ('THE', 'MIGRATION'): 10.519215219330611,
#  ('THE', 'TO'): 7.64474610141447,
#  ('GREAT', 'MIGRATION'): 15.629045873609405,
#  ('GREAT', 'TO'): 13.432648660805901,
#  ('MIGRATION', 'TO'): 15.432648660805901,
#  ('GREAT', 'AMERICA'): 12.307117778722043,
#  ('MIGRATION', 'AMERICA'): 14.722155278000887,
#  ('TO', 'AMERICA'): 13.655041082142349,
#  ('MIGRATION', '1'): 8.59287226105592,
#  ('TO', '1'): 7.718403143139779,
#  ('AMERICA', '1'): 8.177834761777076,
#  ('TO', 'The'): 4.897373284185098,
#  ('AMERICA', 'The'): 6.994234823437687,
#  ('1', 'The'): 2.227521885877429,
#  ('AMERICA', 'Agencies'): 14.307117778722043,
#  ('1', 'Agencies'): 11.177834761777076,
#  ('The', 'Agencies'): 8.356804902822395,
#  ('The', 'American'): 3.276540826995882,
#  ('Agencies', 'American'): 9.374410891309386,
#  ('Agencies', 'Colonization'): 16.8920802794432,
#  ('American', 'Colonization'): 8.959373392030543,
#  ('American', '2'): 4.008088677063571,
#  ('Colonization', '2'): 11.11072056591854,
#  ('American', 'The'): 0.8391355146885835,
#  ('Colonization', 'The'): 6.771842402101239,
#  ('2', 'The'): 0.9904826885765796,
#  ('Colonization', 'Colonial'): 11.804617438192858,
#  ('2', 'Colonial'): 6.438295223947043,
#  ('The', 'Colonial'): 5.006307655738262,
#  ('2', 'Peoples'): 8.940795564476227,
#  ('The', 'Peoples'): 6.186879901380083,
#  ('Colonial', 'Peoples'): 12.804617438192858,
#  ('The', '6'): 0.582017843221222,
#  ('Colonial', '6'): 7.614792879312842,
#  ('Peoples', '6'): 11.702255720563182,
#  ('Colonial', 'The'): 4.269342061572056,
#  ('Peoples', 'The'): 6.186879901380083,
#  ('6', 'The'): 2.1669803439423783,
#  ('Peoples', 'Process'): 16.30711777872204,
#  ('6', 'Process'): 12.702255720563182,
#  ('The', 'Process'): 8.356804902822395,
#  ('The', 'Colonization'): 5.771842402101239,
#  ('Process', 'Colonization'): 17.8920802794432,
#  ('Process', '12'): 12.722155278000887,
#  ('Colonization', '12'): 13.307117778722043,
#  ('Colonization', 'II'): 12.191640561302107,
#  ('12', 'II'): 8.60667806058095,
#  ('COLONIAL', 'AGRICULTURE'): 14.499762856664438,
#  ('COLONIAL', 'INDUSTRY'): 13.66968785810675,
#  ('COLONIAL', 'AND'): 9.243423103404652,
#  ('AGRICULTURE', 'INDUSTRY'): 16.629045873609403,
#  ('AGRICULTURE', 'AND'): 11.880853024019945,
#  ('INDUSTRY', 'AND'): 12.050778025462257,
#  ('AGRICULTURE', 'COMMERCE'): 16.30711777872204,
#  ('INDUSTRY', 'COMMERCE'): 16.8920802794432,
#  ('AND', 'COMMERCE'): 13.050778025462257,
#  ('INDUSTRY', '20'): 11.722155278000887,
#  ('AND', '20'): 8.295890523298787,
#  ('COMMERCE', '20'): 14.307117778722043,
#  ('AND', 'The'): 5.10046514956261,
#  ('COMMERCE', 'The'): 6.771842402101239,
#  ('20', 'The'): 4.186879901380083,
#  ('COMMERCE', 'Land'): 12.570152184555836,
#  ('20', 'Land'): 10.400227183113524,
#  ('The', 'Land'): 5.257269229271481,
#  ('Land', 'Westward'): 10.98518968383468,
#  ('Westward', 'Movement'): 14.389579938914016,
#  ('Westward', '20'): 12.13719277727973,
#  ('Movement', '20'): 11.219654937471702,
#  ('Westward', 'Industrial'): 11.059190265278456,
#  ('Movement', 'Industrial'): 10.556689924749273,
#  ('20', 'Industrial'): 11.059190265278456,
#  ('20', 'Commercial'): 10.552230276558573,
#  ('Industrial', 'Commercial'): 12.4742277645573,
#  ('Industrial', 'Development'): 9.396225252556027,
#  ('Commercial', 'Development'): 12.059190265278456,
#  ('Commercial', '28'): 11.634692436750546,
#  ('Development', '28'): 11.14165242547043,
#  ('Commercial', 'III'): 8.722155278000887,
#  ('Development', 'III'): 8.644152765999612,
#  ('28', 'III'): 9.389579938914016,
#  ('SOCIAL', 'AND'): 12.465815524741101,
#  ('SOCIAL', 'POLITICAL'): 15.017611161527057,
#  ('SOCIAL', 'PROGRESS'): 16.8920802794432,
#  ('AND', 'POLITICAL'): 10.328312000991165,
#  ('AND', 'PROGRESS'): 12.465815524741101,
#  ('POLITICAL', 'PROGRESS'): 16.017611161527057,
#  ('AND', '38'): 10.465815524741101,
#  ('POLITICAL', '38'): 14.432648660805901,
#  ('PROGRESS', '38'): 17.477042780164354,
#  ('POLITICAL', 'The'): 5.312410783463942,
#  ('PROGRESS', 'The'): 6.771842402101239,
#  ('38', 'The'): 7.356804902822395,
#  ('PROGRESS', 'Leadership'): 14.570152184555836,
#  ('38', 'Leadership'): 15.570152184555836,
#  ('The', 'Leadership'): 6.449914307213877,
#  ('Leadership', 'Churches'): 13.98518968383468,
#  ('Churches', '39'): 15.8920802794432,
#  ('Churches', 'Schools'): 15.722155278000887,
#  ('39', 'Schools'): 15.8920802794432,
#  ('39', 'Colleges'): 15.8920802794432,
#  ('Schools', 'Colleges'): 17.30711777872204,
#  ('Schools', '43'): 13.307117778722043,
#  ('Colleges', '43'): 16.477042780164354,
#  ('Colleges', 'The'): 7.771842402101239,
#  ('43', 'The'): 5.356804902822395,
#  ('Colleges', 'Colonial'): 12.804617438192858,
#  ('43', 'Colonial'): 10.804617438192858,
#  ('43', 'Press'): 12.084725357385594,
#  ('The', 'Press'): 5.549449980764791,
#  ('Colonial', 'Press'): 12.319190611022618,
#  ('The', '46'): 5.771842402101239,
#  ('Colonial', '46'): 12.804617438192858,
#  ('Press', '46'): 15.66968785810675,
#  ('Press', 'The'): 6.286415574930997,
#  ('46', 'The'): 7.356804902822395,
#  ('Press', 'Evolution'): 13.499762856664438,
#  ('46', 'Evolution'): 16.30711777872204,
#  ('The', 'Evolution'): 7.771842402101239,
#  ('The', 'Political'): 4.356804902822395,
#  ('Evolution', 'Political'): 13.307117778722043,
#  ('Evolution', 'Institutions'): 16.30711777872204,
#  ('Political', 'Institutions'): 15.477042780164355,
#  ('Political', '48'): 12.570152184555836,
#  ('Institutions', '48'): 17.155114685276992,
#  ('Political', 'IV'): 8.8920802794432,
#  ('Institutions', 'IV'): 13.8920802794432,
#  ('48', 'IV'): 12.155114685276992,
#  ('THE', 'DEVELOPMENT'): 10.519215219330611,
#  ('THE', 'OF'): 9.772101669788322,
#  ('DEVELOPMENT', 'OF'): 11.887578887208258,
#  ('DEVELOPMENT', 'COLONIAL'): 13.499762856664438,
#  ('OF', 'COLONIAL'): 10.51318337242676,
#  ('DEVELOPMENT', 'NATIONALISM'): 15.307117778722043,
#  ('OF', 'NATIONALISM'): 12.150613293042051,
#  ('COLONIAL', 'NATIONALISM'): 15.66968785810675,
#  ('OF', '56'): 10.150613293042051,
#  ('COLONIAL', '56'): 14.084725357385594,
#  ('NATIONALISM', '56'): 17.477042780164354,
#  ('COLONIAL', 'Relations'): 9.44086916761087,
#  ('NATIONALISM', 'Relations'): 13.248224089668474,
#  ('56', 'Relations'): 13.83318659038963,
#  ('Relations', 'Indians'): 7.788792471031177,
#  ('Indians', 'French'): 4.932802773722696,
#  ('French', '57'): 8.97719689308115,
#  ('French', 'The'): 1.85695901573919,
#  ('57', 'The'): 5.356804902822395,
#  ('French', 'Effects'): 7.392234392359994,
#  ('57', 'Effects'): 12.8920802794432,
#  ('The', 'Effects'): 5.771842402101239,
#  ('The', 'Warfare'): 6.771842402101239,
#  ('Effects', 'Warfare'): 15.8920802794432,
#  ('Warfare', 'Colonies'): 14.084725357385594,
#  ('Colonies', '61'): 11.969248139965659,
#  ('Colonies', 'Colonial'): 9.997262516135255,
#  ('61', 'Colonial'): 10.689140220772924,
#  ('Colonies', 'Relations'): 9.44086916761087,
#  ('61', 'Relations'): 10.547784371527381,
#  ('Colonial', 'Relations'): 9.745723749139291,
#  ('Relations', 'British'): 5.253870652809616,
#  ('British', 'Government'): 7.160761248418134,
#  ('British', '64'): 8.312764341863184,
#  ('Government', '64'): 11.570152184555836,
#  ('British', 'Summary'): 7.090371920526736,
#  ('Government', 'Summary'): 10.762797262498232,
#  ('64', 'Summary'): 14.084725357385594,
#  ('64', 'Colonial'): 10.219654937471702,
#  ('Summary', 'Colonial'): 10.997262516135255,
#  ('Summary', 'Period'): 12.084725357385594,
#  ('Colonial', 'Period'): 12.389579938914016,
#  ('Colonial', '73'): 11.219654937471702,
#  ('Period', '73'): 13.8920802794432,
#  ('Colonial', 'PART'): 8.997262516135255,
#  ('Period', 'PART'): 13.084725357385594,
#  ('73', 'PART'): 13.084725357385594,
#  ('Period', 'II'): 9.191640561302107,
#  ('73', 'II'): 10.60667806058095,
#  ('PART', 'II'): 10.384285639244503,
#  ('CONFLICT', 'AND'): 11.880853024019945,
#  ('CONFLICT', 'INDEPENDENCE'): 13.722155278000887,
#  ('CONFLICT', 'V'): 10.914800355943282,
#  ('AND', 'INDEPENDENCE'): 10.880853024019945,
#  ('AND', 'V'): 8.658460602683496,
#  ('INDEPENDENCE', 'V'): 13.236728450830645,
#  ('AND', 'THE'): 9.827660084854351,
#  ('INDEPENDENCE', 'THE'): 9.841143314217973,
#  ...}

# %%
updated_dict
# Out:
# {('As', 'things'): 2,
#  ('As', 'stand'): 1,
#  ('things', 'stand'): 2,
#  ('things', ','): 37,
#  ('stand', ','): 3,
#  ('stand', 'course'): 1,
#  (',', 'course'): 15,
#  ('course', 'instruction'): 2,
#  ('instruction', 'American'): 2,
#  ('instruction', 'history'): 1,
#  ('American', 'history'): 30,
#  ('history', 'public'): 1,
#  ('public', 'schools'): 11,
#  ('public', 'embraces'): 2,
#  ('schools', 'embraces'): 3,
#  ('public', 'three'): 1,
#  ('schools', 'three'): 2,
#  ('embraces', 'three'): 3,
#  ('schools', 'distinct'): 1,
#  ('embraces', 'distinct'): 2,
#  ('three', 'distinct'): 3,
#  ('embraces', 'treatments'): 1,
#  ('three', 'treatments'): 2,
#  ('distinct', 'treatments'): 3,
#  ('treatments', 'subject'): 1,
#  ('subject', '.'): 11,
#  ('Three', 'separate'): 1,
#  ('Three', 'books'): 1,
#  ('separate', 'books'): 2,
#  ('separate', 'used'): 1,
#  ('books', 'used'): 2,
#  ('books', '.'): 11,
#  ('used', '.'): 3,
#  ('First', ','): 7,
#  ('primary', 'book'): 3,
#  ('primary', ','): 8,
#  ('book', ','): 15,
#  (',', 'usually'): 18,
#  ('usually', 'condensed'): 1,
#  ('condensed', 'narrative'): 3,
#  ('condensed', 'emphasis'): 1,
#  ('narrative', 'emphasis'): 2,
#  ('emphasis', 'biographies'): 2,
#  ('biographies', 'anecdotes'): 2,
#  ('biographies', '.'): 1,
#  ('anecdotes', '.'): 3,
#  ('Second', ','): 1,
#  ('advanced', 'text'): 3,
#  ('text', 'seventh'): 1,
#  ('seventh', 'eighth'): 2,
#  ('seventh', 'grade'): 1,
#  ('eighth', 'grade'): 3,
#  ('eighth', ','): 2,
#  ('grade', ','): 3,
#  ('eighth', 'generally'): 1,
#  ('grade', 'generally'): 2,
#  (',', 'generally'): 16,
#  ('grade', 'speaking'): 1,
#  (',', 'speaking'): 21,
#  ('generally', 'speaking'): 3,
#  (',', ','): 5354,
#  ('generally', ','): 2,
#  ('speaking', ','): 21,
#  ('speaking', 'expansion'): 1,
#  (',', 'expansion'): 2,
#  ('expansion', 'elementary'): 1,
#  ('elementary', 'book'): 3,
#  ('book', 'addition'): 1,
#  ('addition', 'forty'): 2,
#  ('forty', 'fifty'): 2,
#  ('forty', 'thousand'): 7,
#  ('fifty', 'thousand'): 12,
#  ('fifty', 'words'): 2,
#  ('thousand', 'words'): 3,
#  ('fifty', '.'): 10,
#  ('thousand', '.'): 20,
#  ('words', '.'): 12,
#  ('Finally', ','): 12,
#  ('high', 'school'): 18,
#  ('high', 'manual'): 4,
#  ('school', 'manual'): 6,
#  ('high', '.'): 32,
#  ('school', '.'): 10,
#  ('manual', '.'): 3,
#  ('This', ','): 50,
#  (',', 'ordinarily'): 6,
#  (',', 'follows'): 4,
#  ('ordinarily', 'follows'): 3,
#  ('ordinarily', 'beaten'): 1,
#  ('follows', 'beaten'): 2,
#  ('follows', 'path'): 1,
#  ('beaten', 'path'): 3,
#  ('beaten', ','): 4,
#  ('path', ','): 4,
#  ('beaten', 'giving'): 1,
#  ('path', 'giving'): 4,
#  (',', 'giving'): 31,
#  ('path', 'fuller'): 1,
#  (',', 'fuller'): 2,
#  ('giving', 'fuller'): 3,
#  (',', 'accounts'): 3,
#  ('giving', 'accounts'): 2,
#  ('fuller', 'accounts'): 3,
#  ('events', 'characters'): 2,
#  ('events', '.'): 14,
#  ('characters', '.'): 3,
#  ('To', 'put'): 3,
#  ('To', 'bluntly'): 1,
#  ('put', 'bluntly'): 2,
#  ('put', ','): 7,
#  ('bluntly', ','): 5,
#  ('assume', 'children'): 1,
#  ('children', 'obtain'): 3,
#  ('children', 'permanent'): 2,
#  ('obtain', 'permanent'): 3,
#  ('children', 'possessions'): 1,
#  ('obtain', 'possessions'): 2,
#  ('permanent', 'possessions'): 3,
#  ('possessions', 'study'): 1,
#  ('study', 'history'): 5,
#  ('history', 'lower'): 1,
#  ('lower', 'grades'): 5,
#  ('lower', '.'): 4,
#  ('grades', '.'): 3,
#  ('If', 'mathematicians'): 1,
#  ('If', 'followed'): 1,
#  ('mathematicians', 'followed'): 2,
#  ('followed', 'method'): 1,
#  ('method', ','): 9,
#  ('method', 'high'): 2,
#  (',', 'high'): 14,
#  ('method', 'school'): 1,
#  (',', 'school'): 4,
#  (',', 'texts'): 1,
#  ('high', 'texts'): 2,
#  ('school', 'texts'): 3,
#  ('school', 'algebra'): 1,
#  ('texts', 'algebra'): 2,
#  ('algebra', 'geometry'): 2,
#  ('algebra', 'would'): 1,
#  ('geometry', 'would'): 3,
#  ('geometry', 'include'): 2,
#  ('would', 'include'): 3,
#  ('would', 'multiplication'): 1,
#  ('include', 'multiplication'): 2,
#  ('include', 'table'): 1,
#  ('multiplication', 'table'): 3,
#  ('multiplication', 'fractions'): 1,
#  ('table', 'fractions'): 2,
#  ('table', '.'): 4,
#  ('fractions', '.'): 3,
#  ('There', ','): 13,
#  ('course', ','): 38,
#  ('course', 'ready'): 1,
#  (',', 'ready'): 10,
#  (',', 'answer'): 6,
#  ('ready', 'answer'): 6,
#  ('answer', 'criticism'): 1,
#  ('criticism', 'advanced'): 3,
#  ('criticism', '.'): 4,
#  ('advanced', '.'): 11,
#  ('It', 'teachers'): 1,
#  ('teachers', 'learned'): 2,
#  ('learned', 'bitter'): 4,
#  ('learned', 'experience'): 2,
#  ('bitter', 'experience'): 9,
#  ('bitter', 'little'): 1,
#  ('experience', 'little'): 2,
#  ('experience', 'history'): 1,
#  ('little', 'history'): 3,
#  ('little', 'pupils'): 1,
#  ('history', 'pupils'): 2,
#  ('history', 'retain'): 1,
#  ('pupils', 'retain'): 3,
#  ('retain', 'pass'): 1,
#  ('pass', 'along'): 6,
#  ('pass', 'regular'): 1,
#  ('along', 'regular'): 2,
#  ('along', 'route'): 1,
#  ('regular', 'route'): 3,
#  ('regular', '.'): 10,
#  ('route', '.'): 9,
#  ('No', 'teacher'): 1,
#  ('No', 'history'): 1,
#  ('teacher', 'history'): 2,
#  ('history', 'deny'): 2,
#  ('deny', '.'): 2,
#  ('standing', 'challenge'): 3,
#  ('standing', 'existing'): 1,
#  ('challenge', 'existing'): 2,
#  ('challenge', 'methods'): 1,
#  ('existing', 'methods'): 3,
#  ('existing', 'historical'): 1,
#  ('methods', 'historical'): 2,
#  ('methods', 'instruction'): 1,
#  ('historical', 'instruction'): 3,
#  ('historical', '.'): 2,
#  ('instruction', '.'): 4,
#  ('If', 'study'): 1,
#  ('made', 'truly'): 3,
#  ('made', 'progressive'): 2,
#  ('truly', 'progressive'): 3,
#  ('made', 'like'): 1,
#  ('truly', 'like'): 2,
#  ('progressive', 'like'): 3,
#  ('progressive', 'study'): 1,
#  ('like', 'study'): 2,
#  ('study', 'mathematics'): 2,
#  ('study', ','): 3,
#  ('mathematics', ','): 4,
#  ('mathematics', 'science'): 2,
#  (',', 'science'): 10,
#  ('science', ','): 17,
#  ('science', 'languages'): 1,
#  (',', 'languages'): 2,
#  ('languages', ','): 10,
#  (',', 'historians'): 2,
#  ('historians', 'assume'): 3,
#  ('historians', 'grave'): 1,
#  ('assume', 'grave'): 2,
#  ('assume', 'responsibility'): 1,
#  ('grave', 'responsibility'): 3,
#  ('grave', 'adding'): 1,
#  ('responsibility', 'adding'): 2,
#  ('adding', 'subject'): 2,
#  ('subject', 'already'): 1,
#  ('already', 'overloaded'): 3,
#  ('already', 'curriculum'): 2,
#  ('overloaded', 'curriculum'): 3,
#  ('already', '.'): 14,
#  ('overloaded', '.'): 2,
#  ('curriculum', '.'): 3,
#  ('If', 'successive'): 1,
#  ('If', 'historical'): 1,
#  ('successive', 'historical'): 3,
#  ('successive', 'texts'): 2,
#  ('historical', 'texts'): 3,
#  ('texts', 'enlarged'): 1,
#  ('enlarged', 'editions'): 3,
#  ('editions', 'first'): 1,
#  ('first', 'text'): 4,
#  ('first', '--'): 4,
#  ('text', '--'): 3,
#  ('text', 'facts'): 1,
#  ('--', 'facts'): 2,
#  ('--', ','): 440,
#  ('facts', ','): 6,
#  ('facts', 'dates'): 1,
#  (',', 'dates'): 2,
#  ('dates', ','): 3,
#  ('dates', 'words'): 1,
#  (',', 'words'): 6,
#  (',', '--'): 104,
#  ('words', '--'): 3,
#  ('words', 'history'): 1,
#  ('--', 'history'): 2,
#  ('--', 'deserves'): 1,
#  ('history', 'deserves'): 3,
#  ('sharp', 'criticism'): 6,
#  ('receiving', 'teachers'): 2,
#  ('teachers', 'science'): 2,
#  ('teachers', ','): 14,
#  ('science', 'civics'): 2,
#  (',', 'civics'): 3,
#  ('civics', ','): 3,
#  ('civics', 'economics'): 1,
#  (',', 'economics'): 2,
#  (',', '.'): 1553,
#  ('economics', '.'): 3,
#  ('In', 'condition'): 1,
#  ('condition', 'affairs'): 4,
#  ('affairs', 'find'): 2,
#  ('find', 'justification'): 2,
#  ('justification', 'offering'): 2,
#  ('offering', 'new'): 2,
#  ('offering', 'high'): 1,
#  ('new', 'high'): 3,
#  ('new', 'school'): 4,
#  ('new', 'text'): 1,
#  ('high', 'text'): 2,
#  ('school', 'text'): 3,
#  ('school', 'American'): 1,
#  ('text', 'American'): 2,
#  ('text', 'history'): 1,
#  ('American', '.'): 247,
#  ('history', '.'): 48,
#  ('Our', 'first'): 1,
#  ('Our', 'contribution'): 1,
#  ('first', 'contribution'): 2,
#  ('first', 'one'): 5,
#  ('contribution', 'one'): 2,
#  ('one', 'omission'): 2,
#  ('one', '.'): 87,
#  ('omission', '.'): 3,
#  ('The', 'time-honored'): 1,
#  ('The', 'stories'): 1,
#  ('time-honored', 'stories'): 2,
#  ('time-honored', 'exploration'): 1,
#  ('stories', 'exploration'): 2,
#  ('exploration', 'biographies'): 1,
#  ('biographies', 'heroes'): 2,
#  ('heroes', 'left'): 2,
#  ('left', '.'): 6,
#  ('We', 'frankly'): 1,
#  ('We', 'hold'): 1,
#  ('frankly', 'hold'): 2,
#  ('frankly', ','): 1,
#  ('hold', ','): 10,
#  (',', 'pupils'): 2,
#  (',', 'know'): 4,
#  ('pupils', 'know'): 3,
#  ('pupils', 'little'): 2,
#  ('know', 'little'): 6,
#  ('know', 'nothing'): 1,
#  ('little', 'nothing'): 2,
#  ('nothing', 'Columbus'): 2,
#  ('nothing', ','): 1,
#  ('Columbus', ','): 11,
#  ('Columbus', 'Cortes'): 2,
#  (',', 'Cortes'): 3,
#  ('Cortes', ','): 4,
#  (',', 'Magellan'): 4,
#  ('Cortes', 'Magellan'): 2,
#  ('Magellan', ','): 6,
#  ('Magellan', 'Captain'): 1,
#  (',', 'Captain'): 15,
#  (',', 'John'): 129,
#  ('Captain', 'John'): 9,
#  ('Captain', 'Smith'): 4,
#  ('John', 'Smith'): 9,
#  ('Smith', 'time'): 1,
#  ('time', 'reach'): 2,
#  ('reach', 'high'): 2,
#  ('reach', 'school'): 1,
#  ('high', ','): 27,
#  ('school', ','): 12,
#  (',', 'useless'): 2,
#  ('useless', 'tell'): 2,
#  ('tell', 'stories'): 1,
#  ('stories', 'perhaps'): 2,
#  ('perhaps', 'fourth'): 2,
#  ('perhaps', 'time'): 1,
#  ('fourth', 'time'): 3,
#  ('fourth', '.'): 2,
#  ('time', '.'): 91,
#  ('It', 'worse'): 1,
#  ('worse', 'useless'): 2,
#  ('worse', '.'): 4,
#  ('useless', '.'): 6,
#  ('It', 'offense'): 1,
#  ('offense', 'teachers'): 1,
#  ('teachers', 'subjects'): 1,
#  ('subjects', 'demonstrated'): 1,
#  ('demonstrated', 'progressive'): 1,
#  ('progressive', 'character'): 2,
#  ('progressive', '.'): 5,
#  ('character', '.'): 32,
#  ('In', 'next'): 1,
#  ('In', 'place'): 30,
#  ('next', 'place'): 3,
#  ('place', 'omitted'): 1,
#  ('omitted', 'descriptions'): 2,
#  ('descriptions', 'battles'): 2,
#  ('descriptions', '.'): 1,
#  ('battles', '.'): 3,
#  ('Our', 'reasons'): 1,
#  ('simple', '.'): 24,
#  ('The', 'strategy'): 1,
#  ('strategy', 'campaign'): 1,
#  ('single', 'battle'): 5,
#  ('battle', 'highly'): 1,
#  ('highly', 'technical'): 3,
#  ('highly', ','): 4,
#  ('technical', ','): 9,
#  ('technical', 'usually'): 1,
#  ('usually', 'highly'): 2,
#  ('usually', 'controversial'): 1,
#  ('highly', 'controversial'): 3,
#  ('controversial', ','): 3,
#  ('highly', 'matter'): 1,
#  ('controversial', 'matter'): 2,
#  (',', 'matter'): 19,
#  ('matter', 'experts'): 1,
#  ('experts', 'differ'): 3,
#  ('experts', 'widely'): 2,
#  ('differ', 'widely'): 3,
#  ('experts', '.'): 1,
#  ('differ', '.'): 2,
#  ('widely', '.'): 15,
#  ('In', 'field'): 7,
#  ('field', 'military'): 2,
#  ('military', 'naval'): 20,
#  ('military', 'operations'): 7,
#  ('naval', 'operations'): 3,
#  ('naval', 'writers'): 1,
#  ('operations', 'writers'): 2,
#  ('writers', 'teachers'): 2,
#  ('teachers', 'history'): 2,
#  ('history', 'mere'): 2,
#  ('history', 'novices'): 1,
#  ('mere', 'novices'): 3,
#  ('mere', '.'): 6,
#  ('novices', '.'): 3,
#  ('To', 'dispose'): 1,
#  ('To', 'Gettysburg'): 1,
#  ('dispose', 'Gettysburg'): 2,
#  ('Gettysburg', 'Wilderness'): 1,
#  ('Wilderness', 'ten'): 2,
#  ('Wilderness', 'lines'): 1,
#  ('ten', 'lines'): 3,
#  ('ten', 'ten'): 1,
#  ('lines', 'ten'): 2,
#  ('lines', 'pages'): 1,
#  ('ten', 'pages'): 3,
#  ('ten', 'equally'): 1,
#  ('pages', 'equally'): 2,
#  ('pages', 'absurd'): 1,
#  ('equally', 'absurd'): 3,
#  ('absurd', 'serious'): 1,
#  ('serious', 'student'): 3,
#  ('serious', 'military'): 1,
#  ('student', 'military'): 2,
#  ('student', 'affairs'): 1,
#  ('military', 'affairs'): 12,
#  ('military', '.'): 37,
#  ('affairs', '.'): 57,
#  ('Any', 'one'): 2,
#  ('Any', 'compares'): 1,
#  ('one', 'compares'): 2,
#  ('compares', 'ordinary'): 2,
#  ('compares', 'textbook'): 1,
#  ('ordinary', 'textbook'): 3,
#  ('ordinary', 'account'): 2,
#  ('textbook', 'account'): 3,
#  ('account', 'single'): 1,
#  ('single', 'Civil'): 3,
#  ('single', 'War'): 2,
#  ('Civil', 'War'): 211,
#  ('single', 'campaign'): 1,
#  ('Civil', 'campaign'): 2,
#  ('War', 'campaign'): 3,
#  ('campaign', 'account'): 1,
#  ('account', 'given'): 3,
#  ('account', 'Ropes'): 1,
#  ('given', 'Ropes'): 2,
#  ('given', ','): 13,
#  ('Ropes', ','): 5,
#  ('Ropes', 'instance'): 1,
#  (',', 'instance'): 17,
#  ('instance', ','): 32,
#  ('instance', 'ask'): 1,
#  (',', 'ask'): 2,
#  ('comment', '.'): 7,
#  ('No', 'youth'): 1,
#  ('No', 'called'): 2,
#  ('No', 'upon'): 1,
#  ('youth', 'called'): 2,
#  ('youth', 'upon'): 2,
#  ('called', 'upon'): 52,
#  ('called', 'serve'): 1,
#  ('upon', 'serve'): 2,
#  ('serve', 'country'): 2,
#  ('country', 'arms'): 2,
#  ('country', 'would'): 1,
#  ('arms', 'would'): 3,
#  ('arms', 'think'): 2,
#  ('would', 'think'): 4,
#  ('would', 'turning'): 1,
#  ('think', 'turning'): 2,
#  ('turning', 'high'): 1,
#  ('school', 'information'): 1,
#  ('manual', 'information'): 2,
#  ('information', 'art'): 1,
#  ('art', 'warfare'): 4,
#  ('art', '.'): 2,
#  ('warfare', '.'): 18,
#  ('The', 'dramatic'): 1,
#  ('The', 'scene'): 2,
#  ('dramatic', 'scene'): 2,
#  ('dramatic', 'episode'): 1,
#  ('scene', 'episode'): 2,
#  ('scene', ','): 13,
#  ('episode', ','): 3,
#  ('episode', 'useful'): 1,
#  (',', 'useful'): 4,
#  ('useful', 'arousing'): 2,
#  ('arousing', 'interest'): 4,
#  ('interest', 'immature'): 1,
#  ('immature', 'pupil'): 3,
#  ('immature', ','): 2,
#  ('pupil', ','): 3,
#  ('immature', 'seems'): 1,
#  ('pupil', 'seems'): 2,
#  (',', 'seems'): 16,
#  ('seems', 'place'): 1,
#  ('place', 'book'): 1,
#  ('book', 'deliberately'): 2,
#  ('book', 'appeals'): 1,
#  ('deliberately', 'appeals'): 3,
#  ('deliberately', 'boys'): 1,
#  ('appeals', 'boys'): 2,
#  ('boys', 'girls'): 4,
#  ('threshold', 'life'): 2,
#  ('threshold', "'s"): 1,
#  ('life', "'s"): 6,
#  ('life', 'serious'): 2,
#  ("'s", 'serious'): 3,
#  ('life', 'responsibilities'): 1,
#  ("'s", 'responsibilities'): 2,
#  ('serious', 'responsibilities'): 3,
#  ("'s", '.'): 100,
#  ('serious', '.'): 8,
#  ('responsibilities', '.'): 3,
#  ('It', 'upon'): 7,
#  ('upon', 'negative'): 3,
#  ('upon', 'features'): 4,
#  ('negative', 'features'): 3,
#  ('upon', ','): 47,
#  ('negative', ','): 2,
#  ('features', ','): 4,
#  ('negative', 'however'): 1,
#  ('features', 'however'): 2,
#  (',', 'however'): 319,
#  ('however', ','): 315,
#  (',', 'rest'): 8,
#  ('rest', 'case'): 4,
#  ('rest', '.'): 18,
#  ('case', '.'): 22,
#  ('It', 'rather'): 1,
#  ('rather', 'upon'): 3,
#  ('rather', 'constructive'): 2,
#  ('upon', 'constructive'): 3,
#  ('rather', 'features'): 1,
#  ('constructive', 'features'): 3,
#  ('upon', '.'): 71,
#  ('constructive', '.'): 2,
#  ('features', '.'): 15,
#  ('_First._', 'We'): 1,
#  ('_First._', 'written'): 1,
#  ('We', 'written'): 2,
#  ('written', 'topical'): 2,
#  ('written', ','): 2,
#  ('topical', ','): 5,
#  (',', 'narrative'): 1,
#  ('narrative', ','): 3,
#  ('narrative', 'history'): 2,
#  (',', 'history'): 5,
#  ('narrative', '.'): 1,
#  ('We', 'tried'): 1,
#  ('tried', 'set'): 2,
#  ('tried', 'forth'): 1,
#  ('set', 'forth'): 57,
#  ('set', 'important'): 1,
#  ('forth', 'important'): 2,
#  ('forth', 'aspects'): 1,
#  ('important', 'aspects'): 3,
#  ('important', ','): 11,
#  ('aspects', ','): 7,
#  ('important', 'problems'): 1,
#  ('aspects', 'problems'): 2,
#  (',', 'problems'): 7,
#  ('problems', ','): 14,
#  ('problems', 'movements'): 1,
#  (',', 'movements'): 2,
#  ('movements', 'period'): 1,
#  ('period', ','): 36,
#  ('period', 'bringing'): 2,
#  (',', 'bringing'): 6,
#  ('bringing', 'narrative'): 1,
#  ('narrative', 'rather'): 3,
#  ('narrative', 'way'): 1,
#  ('rather', 'way'): 2,
#  ('way', 'illustration'): 2,
#  ('way', '.'): 33,
#  ('illustration', '.'): 6,
#  ('_Second._', 'We'): 1,
#  ('_Second._', 'emphasized'): 1,
#  ('We', 'emphasized'): 2,
#  ('emphasized', 'historical'): 2,
#  ('emphasized', 'topics'): 1,
#  ('historical', 'topics'): 3,
#  ('historical', 'help'): 1,
#  ('topics', 'help'): 2,
#  ('help', 'explain'): 2,
#  ('explain', 'nation'): 1,
#  ('nation', 'come'): 2,
#  ('to-day', '.'): 9,
#  ('_Third._', 'We'): 1,
#  ('_Third._', 'dwelt'): 1,
#  ('We', 'dwelt'): 2,
#  ('We', 'fully'): 1,
#  ('dwelt', 'fully'): 3,
#  ('dwelt', 'upon'): 5,
#  ('fully', 'upon'): 3,
#  ('fully', 'social'): 1,
#  ('upon', 'social'): 5,
#  ('social', 'economic'): 2,
#  ('social', 'aspects'): 1,
#  ('economic', 'aspects'): 9,
#  ('aspects', 'history'): 1,
#  ('history', ','): 24,
#  ('history', 'especially'): 2,
#  (',', 'especially'): 89,
#  (',', 'relation'): 3,
#  ('especially', 'relation'): 4,
#  ('relation', 'politics'): 1,
#  ('politics', 'period'): 2,
#  ('period', '.'): 14,
#  ('_Fourth._', 'We'): 1,
#  ('_Fourth._', 'treated'): 1,
#  ('We', 'treated'): 2,
#  ('treated', 'causes'): 2,
#  ('causes', 'results'): 2,
#  ('results', 'wars'): 3,
#  ('results', ','): 9,
#  ('wars', ','): 32,
#  ('wars', 'problems'): 1,
#  ('problems', 'financing'): 2,
#  ('financing', 'sustaining'): 2,
#  ('financing', 'armed'): 1,
#  ('sustaining', 'armed'): 3,
#  ('sustaining', 'forces'): 2,
#  ('armed', 'forces'): 18,
#  ('sustaining', ','): 1,
#  ('armed', ','): 19,
#  ('forces', ','): 26,
#  ('armed', 'rather'): 1,
#  ('forces', 'rather'): 2,
#  (',', 'rather'): 41,
#  (',', 'military'): 25,
#  ('rather', 'military'): 2,
#  ('rather', 'strategy'): 1,
#  ('military', 'strategy'): 9,
#  ('strategy', '.'): 3,
#  ('These', 'subjects'): 1,
#  ('subjects', 'belong'): 2,
#  ('belong', 'history'): 1,
#  ('history', 'civilians'): 2,
#  ('civilians', '.'): 3,
#  ('These', 'matters'): 1,
#  ('matters', 'civilians'): 2,
#  ('civilians', 'understand'): 2,
#  ('civilians', '--'): 1,
#  ('understand', '--'): 3,
#  ('understand', 'matters'): 2,
#  ('--', 'matters'): 4,
#  ('matters', 'must'): 1,
#  ('must', 'understand'): 3,
#  ('must', ','): 16,
#  ('understand', ','): 8,
#  ('play', 'well'): 3,
#  ('play', 'part'): 3,
#  ('well', 'part'): 4,
#  ('part', 'war'): 2,
#  ('war', 'peace'): 5,
#  ('war', '.'): 176,
#  ('peace', '.'): 39,
#  ('_Fifth._', 'By'): 1,
#  ('_Fifth._', 'omitting'): 1,
#  ('By', 'omitting'): 2,
#  ('By', 'period'): 1,
#  ('omitting', 'period'): 2,
#  ('period', 'exploration'): 2,
#  ('exploration', ','): 4,
#  ('able', 'enlarge'): 2,
#  ('enlarge', 'treatment'): 2,
#  ('We', 'given'): 1,
#  ('We', 'special'): 1,
#  ('given', 'special'): 3,
#  ('given', 'attention'): 2,
#  ('special', 'attention'): 3,
#  ('attention', 'history'): 1,
#  ('history', 'current'): 1,
#  ('current', 'questions'): 3,
#  ('current', 'must'): 1,
#  ('questions', 'must'): 2,
#  ('questions', 'form'): 1,
#  ('must', 'form'): 3,
#  ('must', 'subject'): 1,
#  ('form', 'subject'): 2,
#  ('form', 'matter'): 1,
#  ('subject', 'matter'): 3,
#  ('subject', 'sound'): 1,
#  ('matter', 'sound'): 2,
#  ('matter', 'instruction'): 1,
#  ('sound', 'instruction'): 3,
#  ('sound', 'citizenship'): 1,
#  ('instruction', 'citizenship'): 2,
#  ('citizenship', '.'): 11,
#  ('_Sixth._', 'We'): 1,
#  ('_Sixth._', 'borne'): 1,
#  ('We', 'borne'): 2,
#  ('borne', 'mind'): 2,
#  ('mind', 'America'): 2,
#  ('mind', ','): 9,
#  ('America', ','): 136,
#  ('unique', 'characteristics'): 3,
#  ('unique', ','): 2,
#  ('characteristics', ','): 3,
#  (',', 'part'): 17,
#  ('part', 'general'): 1,
#  ('general', 'civilization'): 3,
#  ('general', '.'): 38,
#  ('civilization', '.'): 21,
#  ('Accordingly', 'given'): 1,
#  ('given', 'diplomacy'): 3,
#  ('diplomacy', ','): 16,
#  ('given', 'foreign'): 1,
#  ('diplomacy', 'foreign'): 2,
#  (',', 'foreign'): 32,
#  ('diplomacy', 'affairs'): 1,
#  (',', 'affairs'): 6,
#  ('foreign', 'affairs'): 9,
#  ('foreign', ','): 44,
#  ('affairs', ','): 41,
#  ('foreign', 'world'): 4,
#  ('affairs', 'world'): 2,
#  (',', 'world'): 7,
#  ('affairs', 'relations'): 1,
#  (',', 'relations'): 11,
#  ('world', 'relations'): 3,
#  ('world', ','): 27,
#  ('relations', ','): 17,
#  (',', 'reciprocal'): 1,
#  ('reciprocal', 'influences'): 3,
#  ('reciprocal', 'nations'): 1,
#  ('influences', 'nations'): 2,
#  ('nations', 'appropriate'): 2,
#  ('nations', 'place'): 1,
#  ('appropriate', 'place'): 3,
#  ('appropriate', '.'): 14,
#  ('place', '.'): 18,
#  ('_Seventh._', 'We'): 1,
#  ('_Seventh._', 'deliberately'): 1,
#  ('We', 'deliberately'): 2,
#  ('We', 'aimed'): 2,
#  ('deliberately', 'aimed'): 6,
#  ('deliberately', 'standards'): 1,
#  ('aimed', 'standards'): 2,
#  ('standards', 'maturity'): 2,
#  ('standards', '.'): 1,
#  ('maturity', '.'): 4,
#  ('The', 'study'): 1,
#  ('study', 'mere'): 1,
#  ('mere', 'narrative'): 3,
#  ('mere', 'calls'): 2,
#  ('narrative', 'calls'): 3,
#  ('mere', 'mainly'): 1,
#  ('narrative', 'mainly'): 2,
#  ('calls', 'mainly'): 3,
#  ('mainly', 'use'): 1,
#  ('use', 'memory'): 1,
#  ('memory', '.'): 5,
#  ('aimed', 'stimulate'): 2,
#  ('aimed', 'habits'): 1,
#  ('stimulate', 'habits'): 3,
#  ('stimulate', 'analysis'): 1,
#  ('habits', 'analysis'): 2,
#  ('habits', ','): 10,
#  ('analysis', ','): 4,
#  ('analysis', 'comparison'): 2,
#  (',', 'comparison'): 3,
#  ('comparison', ','): 10,
#  (',', 'association'): 11,
#  ('comparison', 'association'): 2,
#  ('association', ','): 13,
#  (',', 'reflection'): 4,
#  ('association', 'reflection'): 2,
#  ('reflection', ','): 3,
#  ('reflection', 'generalization'): 1,
#  (',', 'generalization'): 2,
#  ('generalization', '--'): 3,
#  ('generalization', 'habits'): 2,
#  ('--', 'habits'): 3,
#  ('generalization', 'calculated'): 1,
#  ('--', 'calculated'): 2,
#  ('habits', 'calculated'): 3,
#  ('habits', 'enlarge'): 1,
#  ('calculated', 'enlarge'): 2,
#  ('enlarge', 'well'): 2,
#  ('well', 'inform'): 2,
#  ('inform', 'mind'): 2,
#  ('inform', '.'): 1,
#  ('mind', '.'): 21,
#  ('great', 'pains'): 3,
#  ('great', 'make'): 2,
#  ('pains', 'make'): 2,
#  ('make', 'text'): 2,
#  ('make', 'clear'): 1,
#  ('text', 'clear'): 3,
#  ('text', ','): 3,
#  ('clear', ','): 14,
#  ('text', 'simple'): 1,
#  ('clear', 'simple'): 4,
#  (',', 'simple'): 9,
#  ('simple', ','): 16,
#  ('simple', 'direct'): 1,
#  (',', 'direct'): 21,
#  (',', ';'): 77,
#  ('direct', ';'): 4,
#  ('earnestly', 'sought'): 6,
#  ('earnestly', 'stretch'): 1,
#  ('sought', 'stretch'): 2,
#  ('stretch', 'intellects'): 2,
#  ('intellects', 'readers'): 1,
#  ('readers', '--'): 3,
#  ('readers', 'put'): 1,
#  ('--', 'put'): 2,
#  ('put', 'upon'): 9,
#  ('upon', 'mettle'): 2,
#  ('mettle', '.'): 3,
#  ('receive', 'last'): 2,
#  ('last', 'formal'): 1,
#  ('formal', 'instruction'): 3,
#  ('instruction', 'high'): 1,
#  ('The', 'world'): 4,
#  ('The', 'soon'): 1,
#  ('world', 'soon'): 2,
#  ('world', 'expect'): 1,
#  ('soon', 'expect'): 3,
#  ('soon', 'maturity'): 2,
#  ('expect', 'maturity'): 3,
#  ('Their', 'achievements'): 1,
#  ('Their', 'depend'): 1,
#  ('achievements', 'depend'): 2,
#  ('achievements', 'upon'): 1,
#  ('depend', 'upon'): 6,
#  ('depend', 'possession'): 1,
#  ('upon', 'possession'): 2,
#  ('possession', 'powers'): 1,
#  ('powers', 'memory'): 2,
#  ('powers', 'alone'): 1,
#  ('memory', 'alone'): 3,
#  ('alone', '.'): 27,
#  ('The', 'effectiveness'): 1,
#  ('effectiveness', 'citizenship'): 1,
#  ('citizenship', 'republic'): 1,
#  ('republic', 'measured'): 1,
#  ('measured', 'excellence'): 1,
#  ('excellence', 'judgment'): 1,
#  ('judgment', 'well'): 2,
#  ('well', 'fullness'): 1,
#  ('fullness', 'information'): 1,
#  ('information', '.'): 3,
#  ('C.A.B', '.'): 1,
#  ('M.R.B', '.'): 1,
#  ('NEW', 'YORK'): 13,
#  ('NEW', 'CITY'): 7,
#  ('NEW', ','): 1,
#  ('YORK', 'CITY'): 11,
#  ('YORK', ','): 2,
#  ('CITY', ','): 3,
#  ('YORK', 'February'): 1,
#  ('CITY', 'February'): 2,
#  (',', 'February'): 11,
#  ('CITY', '8'): 1,
#  (',', '8'): 2,
#  ('February', '8'): 6,
#  ('February', ','): 72,
#  ('8', ','): 20,
#  ('February', '1921'): 1,
#  ('8', '1921'): 2,
#  (',', '1921'): 3,
#  ('8', '.'): 35,
#  ('1921', '.'): 3,
#  ('=A', 'SMALL'): 1,
#  ('=A', 'LIBRARY'): 1,
#  ('=A', 'IN'): 1,
#  ('SMALL', 'LIBRARY'): 2,
#  ('SMALL', 'IN'): 2,
#  ('LIBRARY', 'IN'): 3,
#  ('SMALL', 'AMERICAN'): 1,
#  ('LIBRARY', 'AMERICAN'): 2,
#  ('IN', 'AMERICAN'): 3,
#  ('LIBRARY', 'HISTORY='): 1,
#  ('IN', 'HISTORY='): 2,
#  ('AMERICAN', 'HISTORY='): 3,
#  ('IN', '_=SINGLE'): 1,
#  ('AMERICAN', '_=SINGLE'): 2,
#  ('HISTORY=', '_=SINGLE'): 3,
#  ('AMERICAN', 'VOLUMES'): 1,
#  ('HISTORY=', 'VOLUMES'): 2,
#  ('_=SINGLE', 'VOLUMES'): 3,
#  ('HISTORY=', ':'): 1,
#  ('_=SINGLE', ':'): 2,
#  ('VOLUMES', ':'): 3,
#  ('_=SINGLE', '=_'): 1,
#  ('VOLUMES', '=_'): 2,
#  (':', '=_'): 6,
#  ('VOLUMES', 'BASSETT'): 1,
#  (':', 'BASSETT'): 2,
#  ('=_', 'BASSETT'): 3,
#  (':', ','): 147,
#  ('=_', ','): 2,
#  ('BASSETT', ','): 3,
#  ('=_', 'J.S'): 1,
#  ('BASSETT', 'J.S'): 2,
#  (',', 'J.S'): 3,
#  ('BASSETT', '.'): 1,
#  ('J.S', '.'): 9,
#  ('_A', 'Short'): 1,
#  ('_A', 'History'): 9,
#  ('Short', 'History'): 2,
#  ('History', 'United'): 24,
#  ('United', 'States_'): 213,
#  ('United', 'ELSON'): 2,
#  ('States_', 'ELSON'): 3,
#  ('United', ','): 256,
#  ('States_', ','): 158,
#  ('ELSON', ','): 3,
#  ('States_', 'H.W'): 1,
#  ('ELSON', 'H.W'): 2,
#  (',', 'H.W'): 5,
#  ('ELSON', '.'): 1,
#  ('H.W', '.'): 8,
#  ('_History', 'United'): 31,
#  ('United', 'States'): 1159,
#  ('United', 'America_'): 1,
#  ('States', 'America_'): 3,
#  ('States', '_=SERIES'): 1,
#  ('America_', '_=SERIES'): 3,
#  ('America_', ':'): 2,
#  ('_=SERIES', ':'): 3,
#  ('America_', '=_'): 1,
#  ('_=SERIES', '=_'): 2,
#  ('_=SERIES', '``'): 1,
#  (':', '``'): 336,
#  ('=_', '``'): 3,
#  (':', 'EPOCHS'): 1,
#  ('=_', 'EPOCHS'): 2,
#  ('``', 'EPOCHS'): 3,
#  ('=_', 'OF'): 1,
#  ('``', 'OF'): 4,
#  ('EPOCHS', 'OF'): 3,
#  ('``', 'AMERICAN'): 1,
#  ('EPOCHS', 'AMERICAN'): 2,
#  ('OF', 'AMERICAN'): 9,
#  ('EPOCHS', 'HISTORY'): 1,
#  ('OF', 'HISTORY'): 2,
#  ('AMERICAN', 'HISTORY'): 3,
#  ('OF', ','): 9,
#  ('AMERICAN', ','): 2,
#  ('HISTORY', ','): 3,
#  ('AMERICAN', "''"): 1,
#  ('HISTORY', "''"): 2,
#  (',', "''"): 944,
#  ('HISTORY', 'EDITED'): 1,
#  (',', 'EDITED'): 4,
#  ("''", 'EDITED'): 6,
#  (',', 'BY'): 5,
#  ("''", 'BY'): 4,
#  ('EDITED', 'BY'): 6,
#  ("''", 'A.B'): 1,
#  ('EDITED', 'A.B'): 2,
#  ('BY', 'A.B'): 3,
#  ('EDITED', '.'): 2,
#  ('BY', '.'): 4,
#  ('A.B', '.'): 14,
#  ('HART', 'HART'): 1,
#  ('HART', ','): 3,
#  ('HART', 'A.B'): 3,
#  (',', 'A.B'): 3,
#  ('HART', '.'): 1,
#  ('_Formation', 'Union_'): 1,
#  ('Union_', 'THWAITES'): 3,
#  ('Union_', ','): 2,
#  ('THWAITES', ','): 3,
#  ('Union_', 'R.G'): 1,
#  ('THWAITES', 'R.G'): 2,
#  (',', 'R.G'): 3,
#  ('THWAITES', '.'): 1,
#  ('R.G', '.'): 6,
#  ('_The', 'Colonies_'): 1,
#  ('_The', 'WILSON'): 1,
#  ('_The', ','): 11,
#  ('Colonies_', 'WILSON'): 2,
#  ('Colonies_', ','): 5,
#  ('WILSON', ','): 3,
#  ('Colonies_', 'WOODROW'): 1,
#  ('WILSON', 'WOODROW'): 2,
#  (',', 'WOODROW'): 3,
#  ('WILSON', '.'): 1,
#  ('WOODROW', '.'): 3,
#  ('_Division', 'Reunion_'): 1,
#  ('_Division', '``'): 1,
#  ('Reunion_', '``'): 3,
#  ('Reunion_', 'RIVERSIDE'): 2,
#  ('``', 'RIVERSIDE'): 3,
#  ('Reunion_', 'SERIES'): 1,
#  ('``', 'SERIES'): 2,
#  ('RIVERSIDE', 'SERIES'): 3,
#  ('``', ','): 196,
#  ('RIVERSIDE', ','): 2,
#  ('SERIES', ','): 3,
#  ('RIVERSIDE', "''"): 1,
#  ('SERIES', "''"): 2,
#  ('SERIES', 'EDITED'): 1,
#  ("''", 'W.E'): 1,
#  ('EDITED', 'W.E'): 2,
#  ('BY', 'W.E'): 3,
#  ...}
